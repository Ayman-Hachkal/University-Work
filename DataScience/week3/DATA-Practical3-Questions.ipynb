# %% [markdown]
# # DATA Practical 3 - Model Answers
#
#
#
#
# ## All You Need to Know About Google Play Store
#
# **Google Play store** ([https://play.google.com/store?hl=en](https://play.google.com/store?hl=en)) is a digital distribution service operated and developed by Google. It serves as the official app store for the Android operating system, allowing users to browse and download applications developed with the Android software development kit (SDK) and published through Google. [Wikipedia](https://en.wikipedia.org/wiki/Google_Play).
#
# **DataVision** has scraped the Google Play store  and acquired data for several Android applications. Since data from the Play Store apps has great potential to drive app-making businesses to success, DataVision wants to investigate whether any actionable insights can be drawn for developers to work on and capture the Android market!
#
# #### Your tasks are to explore this dataset and generade actionable knowledge.
#
#
# #### This Jupyter Notebook will be presented to  Google stakeholders who have limited knowledge about data science. So, your findings should be complemented by a suitable justification explaining what you observe and, when applicable, what does this observation  mean and, possibly, why it occurs.
#
# * For each question (task) a description is provided accompanied (most of the time) by two cells: one for writing the Python code and another for providing the justification. Feel free to add more cells if you feel they are needed, but keep the cells corresponding to the same question close by.
#
#
#
# (1) Read **Chapter 2 - Introduction to NumPy from the Python Data Science Handbook** (https://jakevdp.github.io/PythonDataScienceHandbook/02.00-introduction-to-numpy.html)
#
#
# (2) Read **Chapter 3: Dapa Manipulation with Pandas from the Python Data Science Handbook** (https://jakevdp.github.io/PythonDataScienceHandbook/03.00-introduction-to-pandas.html)
#
# (3) If you haven't already done so, complete the tutorial on Numpy and Pandas to become familiar with the libraries.
#
#
# **Numpy API Reference**: https://numpy.org/doc/stable/reference
#
# **Pandas API Reference**:  https://pandas.pydata.org/pandas-docs/stable/reference/index.html
#
# ***

# %% [markdown]
# ### Part 1: Getting dataset
#
# The Google dataset is available on VLE (look for googleplaystore.csv in the Practicals section)
#
# Before doing the tasks below, you may want to explore the dataset using a spreadsheet editor (e.g., Excel) to get a high-level view of the dataset.
#
# **T1) Assign loaded Google PlayStore dataset (.csv) to a variable called df using the pandas library**
#
# **Note**: You have to download the dataset on your local machine and then load it onto the Jupyter Notebook

# %%
import pandas as pd 
import numpy as np

# Answer:
fileCSV = "googlePlaystore.csv"

# %%
#Write your answer here
df = pd.read_csv(fileCSV)

# %% [markdown]
# ***
#
# ### Part 2: Checking, cleaning and analysing the dataset
#
# **You need to use the dataframe df obtained in Part 1 to perform all of the following tasks.**

# %% [markdown]
# **T2i) Print the first 10 records of the dataframe**

# %%
#Write your answer here
df.head(10)
# Out:
#                                                App Category  Rating  Reviews  \
# 0                                Truth or Dare Pro   DATING     NaN        0
# 1  Private Dating, Hide App- Blue for PrivacyHider   DATING     NaN        0
# 2                               Dating White Girls   DATING     NaN        0
# 3                                     Geeks Dating   DATING     NaN        0
# 4                               CAM5678 Video Chat   DATING     NaN        0
# 5                          Video chat live advices   DATING     NaN        0
# 6                                Pet Lovers Dating   DATING     NaN        0
# 7                                     Latin Dating   DATING     NaN        0
# 8                                      Wifi Mingle   DATING     NaN        0
# 9                            HOW TO ASK A GIRL OUT   DATING     NaN        0
#
#     Size Installs  Type  Price Content Rating  Genres       Last Updated  \
# ...

# %% [markdown]
# **T2ii) Print the last 3 records of the dataframe**

# %%
#Write your answer here

df.tail(3)
# Out:
#                       App       Category  Rating   Reviews  \
# 10836  WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 10837            Facebook         SOCIAL     4.1  78128208
# 10838            Facebook         SOCIAL     4.1  78158306
#
#                      Size        Installs  Type Price Content Rating  \
# 10836  Varies with device  1,000,000,000+  Free     0       Everyone
# 10837  Varies with device  1,000,000,000+  Free     0           Teen
# 10838  Varies with device  1,000,000,000+  Free     0           Teen
#
#               Genres    Last Updated         Current Ver         Android Ver
# 10836  Communication  August 3, 2018  Varies with device  Varies with device
# 10837         Social  August 3, 2018  Varies with device  Varies with device
# 10838         Social  August 3, 2018  Varies with device  Varies with device

# %% [markdown]
# **T3) Get general info about the dataset**
#
# * Hint: use the info() method of the dataframe

# %%
#Write your answer here

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  str
#  1   Category        10839 non-null  str
#  2   Rating          9365 non-null   float64
#  3   Reviews         10839 non-null  int64
#  4   Size            10839 non-null  str
#  5   Installs        10839 non-null  str
#  6   Type            10838 non-null  str
#  7   Price           10839 non-null  str
#  8   Content Rating  10839 non-null  str
#  9   Genres          10839 non-null  str
#  10  Last Updated    10839 non-null  str
#  11  Current Ver     10831 non-null  str
#  12  Android Ver     10837 non-null  str
# dtypes: float64(1), int64(1), str(11)
# memory usage: 1.1 MB

# %% [markdown]
# **T4) Explore the dataset and try to understand the meaning of each column. For each column, write its meaning and its data type**

# %% [markdown]
# - App:            Name of the application (Text)
# - Category:       Category the app belongs to (Categorical - nominal)
# - Rating:         The Star rating of the app (Numerical - Discrete)
# - Reviews:        How many reviews there are (Numerical - Discrete)
# - Size:           How large the app size is  (Numerical - Continuos)
# - Installs:       How many downloads the app has (Numerical - Discrete)
# - Type:           If app is paid or free (Categorical - Ordinal)
# - Price:

# %% [markdown]
# **T5) Find the size of the dataset by reporting the number of rows and columns.**

# %%
#Write your answer here


#(Note: if you use the size property of a Dataframe it will output the product of #rows x #columns)
print("dataframe is" , df.shape[0] , "Rows")
print("dataframe is " , df.shape[1] , " Cols")
# Out:
# dataframe is 10839 Rows
# dataframe is  13  Cols

# %% [markdown]
# **T6) Get the name of the columns of the dataframe**

# %%
#Write your answer here
print(df.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %% [markdown]
# **T7) Rename the column names by removing spaces between words and replacing Ver with Version.**

# %%
#Write your answer here
df.columns = df.columns.str.replace(" ", "")
df.columns = df.columns.str.replace("Ver", "Version")
print(df.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'ContentRating', 'Genres', 'LastUpdated', 'CurrentVersion',
#        'AndroidVersion'],
#       dtype='str')

# %% [markdown]
# **T8) How many duplicated records exist?**
#
# * **Note**: A record is duplicated if all its entries are identical with another record
# * Hint: Check the duplicated method in Pandas

# %%
#Write your answer here
dupe = df.duplicated()
dupeRecord = df[dupe]
print(dupe)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10834    False
# 10835    False
# 10836     True
# 10837    False
# 10838    False
# Length: 10839, dtype: bool

# %% [markdown]
# **T9 From the duplicated records, determine how many correspond to apps whose name in the App column contains the phrase blood pressure, and print them**

# %%
#Write your answer here

dupeRecord[dupeRecord["App"].str.contains("blood pressure")]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, ContentRating, Genres, LastUpdated, CurrentVersion, AndroidVersion]
# Index: []

# %% [markdown]
# **T10) Let's look more closely into the dataset. Are there more duplicates?**
#
# **Hint:** Check the duplicated function of Pandas to understand how the function operates. Do you need to specify what information to consider when checking for duplicates?

# %%
#Write your answer here
allDupe = df[df.duplicated(keep=False)]
print(allDupe.count())
# Out:
# App               893
# Category          893
# Rating            876
# Reviews           893
# Size              893
# Installs          893
# Type              893
# Price             893
# ContentRating     893
# Genres            893
# LastUpdated       893
# CurrentVersion    893
# AndroidVersion    893
# dtype: int64

# %% [markdown]
# **T11) Identify the application with the highest number of duplicate records. Report how many duplicate records it has and list the details of these duplicate entries.**
#
# **Hint:** How can you count the records of a dataframe?

# %%
#Write your answer here

print(allDupe.App.value_counts())

# CBS Sports App - Scores, News, Stats & Watch Live has the most duplicates at 7
print(df[df.App.str.contains("CBS Sports App - Scores, News, Stats & Watch Live")])
# Out:
# App
# CBS Sports App - Scores, News, Stats & Watch Live     7
# ESPN                                                  6
# Bleacher Report: sports news, scores, & highlights    5
# theScore: Live Sports Scores, News, Stats & Videos    5
# Meetup                                                4
#                                                      ..
# Subway Surfers                                        2
# Clash of Clans                                        2
# Messenger – Text and Video Chat for Free              2
# Instagram                                             2
# WhatsApp Messenger                                    2
# Name: count, Length: 400, dtype: int64
#                                                     App Category  Rating  \
# 8594  CBS Sports App - Scores, News, Stats & Watch Live   SPORTS     4.3
# 8595  CBS Sports App - Scores, News, Stats & Watch Live   SPORTS     4.3
# 8596  CBS Sports App - Scores, News, Stats & Watch Live   SPORTS     4.3
# ...

# %%
#Write your answer here

# %% [markdown]
# **T12) Examine the records for the app you identified in Task T11. Why do you think duplicate records exist for this app? Provide your reasoning.**

# %%
#Write your answer here
#Could be for different devices due to the varies with device.

# %% [markdown]
# Possible reasons include:
#
# * The only difference between some entries is the Category (e.g. GAME vs FAMILY), which suggests that the app may have been classified inconsistently.
# * Several entries show different numbers of reviews, which indicates that the records may have been captured at different time points during data collection.

# %% [markdown]
# **T13) Remove duplicate records from the dataframe, assuming the data was collected sequentially. Decide which entry to keep, and then print the number of rows and columns in the updated dataset.**
#
# **Hint:** You may want to check the documentation of the drop_duplicates function

# %%
#Write your answer here
df.drop_duplicates(subset="App", keep="first", inplace=True)
print(df.count())
# Out:
# App               9658
# Category          9658
# Rating            8194
# Reviews           9658
# Size              9658
# Installs          9658
# Type              9657
# Price             9658
# ContentRating     9658
# Genres            9658
# LastUpdated       9658
# CurrentVersion    9650
# AndroidVersion    9656
# dtype: int64

# %% [markdown]
# **T14) How many unique values exist under the Price variable? Print the first five unique prices.**

# %%
#Write your answer here
for i in range(5):
    print(df.Price.unique()[i])
# Out:
# $1.49
# $2.99
# 0
# $14.99
# $5.99

# %% [markdown]
# **T15i) Write a function moneyWithoutCurrencySymbol that takes a string and returns the string as a float without the currency symbol (if exists)**

# %%
#Write your answer here

def moneyWithoutCurrencySymbol(money : str) -> float:
    return float(money.replace("$", ""))

# %% [markdown]
# **T15ii) Convert the Price column into a float variable. Before performing the conversion, display the first 5 values and the data type of the column. Then repeat the same checks after conversion to confirm that the transformation was successful.**
#
# **Hint:**
#
# * You may want to use the function from task T15i
# * You may want to check https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.apply.html
# * Alternatively, you may want to check https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_numeric.html

# %%
#Write your answer here

for i in range(5):
    print(moneyWithoutCurrencySymbol(
        df.Price.unique()[i]
    ))
# Out:
# 1.49
# 2.99
# 0.0
# 14.99
# 5.99

# %% [markdown]
# **T16i) How many missing data (NaN) exist for each variable?**

# %%
#Write your answer here

print(df.notna().count() - df.count())
# Out:
# App                  0
# Category             0
# Rating            1464
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# ContentRating        0
# Genres               0
# LastUpdated          0
# CurrentVersion       8
# AndroidVersion       2
# dtype: int64

# %% [markdown]
# **T16ii) Impute the missing values in the categorical columns (Type, CurrentVersion, and AndroidVersion) with the mode of each column. Show the number of missing values in these columns before and after the imputation.**
#
# **Hint:** Check Chapter 3 of the Python Data Science Handbook

# %%
#Write your answer here

# %% [markdown]
# **T16iii) What would be an appropriate value to impute for the categorical columns "Rating"? Apply the imputation.**
#
# **Note:** Different imputation may be possible depending on your assumption.

# %%
#Write your answer here

# %% [markdown]
# **T17i) Display all the unique values that appear in the Installs column.**

# %%
#Write your answer here

# %% [markdown]
# **T17ii) Based on the unique values you found in Task T17i, identify any inconsistent entries in the Installs column. If such values exist, suggest and apply appropriate cleaning steps, then verify the result**
#
# * Hint: Check the Pandas method loc (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html#pandas.DataFrame.loc)

# %%
#Write your answer here

# %% [markdown]
# **T18) Are there any logical inconsistencies in the *Type* and *Price* variables? Specifically, are there any applications labelled as *Free* for which you have to pay, or any applications labelled as *Paid* that are available for free? Verify the integrity of the dataset using these conditions.**

# %%
#Write your answer here

# %% [markdown]
# **T19i) Are there any logical inconsistencies in the *Reviews* and *Rating* variables? Specifically, are there any applications with zero reviews that nevertheless have a rating greater than zero? Verify the integrity of the dataset using this condition.**

# %%
#Write your answer here

# %% [markdown]
# **T19ii) Based on the results from task T19i, suggest an appropriate method to correct the identified inconsistency.**

# %%
#Write your answer here

# %% [markdown]
# **T20i) Get some descriptive statistics for the dataset**

# %%
#Write your answer here

# %% [markdown]
# **T20i) Plot the histogram of the Price variable using 20 bins**
#
# * Hint: See https://www.w3schools.com/python/matplotlib_histograms.asp

# %%
#Write your answer here

# %% [markdown]
# **T21i) Investigate whether the *Price* variable contains any outliers. Should any preparatory steps be taken before this analysis? Apply the IQR method to examine the data and describe your observations.**

# %%
#We need to keep only the Paid applications
#Write your answer here

# %%
#Write your answer here

# %% [markdown]
# **T21ii) Do the same using the standard deviation method for identifying outliers for the Price**

# %%
#Write your answer here

# %% [markdown]
# **T22) Use an appropriate method to investigate the potential existence of outliers for the Reviews variable**

# %%
#Write your answer here

# %%
#Write your answer here

# %%
#Write your answer here

# %% [markdown]
# **T23) (Funny) What is weird about the most expensive applications which are at or above the 99.9th percentile?**

# %%
#Write your answer here

# %% [markdown]
# ## Bonus

# %% [markdown]
# **T24i) Check the type of the variable indicating the last time the application was updated and convert it into the appropriate format**
#
# **Hint:**
#
# * You may want to check https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html
#
# * Pay attention to the date format and the month type
#
# * You may also want to check https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html

# %%
#Write your answer here

# %% [markdown]
# **T24ii) Which application was updated least recently and when did this happen?**

# %%
#Write your answer here

# %% [markdown]
# **T25) Create a new column that indicates the difference between the last updated variable and the current date.**

# %%
#Write your answer here

# %% [markdown]
# **T26i) Perform the necessary processing tasks to convert the Size variable into a float using a common metric (i.e., which will enable to compare records between each other using the size value). Set records whose value is "Varies with device" to 1**

# %%
#Write your answer here

# %% [markdown]
# **T26ii) Which is the smallest application and what is its size?**

# %%
#Write your answer here

# %% [markdown]
# **T26iii) Among the largest applications, which category is the most common, and which applications belong to this category? **

# %%
#Write your answer here

# %% [markdown]
# ### Should you finish earlier/want to practice at home, you could
#
# * Check that the values of Rating variable is within the limits [0,5]
# * Save the updated file as a new table
# * Any other analysis that you might could generate some useful insight.
