# %%
#1. This is used to create a database and read data from a csv file into the database
import sqlite3
import pandas as pd

# Path to your CSV file
csv_file = "LusitaniaManifest.csv"

# Name of SQLite database file (will be created if it doesn't exist)
db_file = "example.db"

# Name of table to create
table_name = "ship_data"

#helper functions
def connect_to_database(db_file):
    con = sqlite3.connect(db_file)
    print (con)
    return con

def read_data_into_database(db_base, csv_file, table_name):
    #This code uses pandas frame to read data from the csv file and then uploads it into a database
    #The .to_sql is a function tied to the pandas dataframe for loading .csv files into database

    # Write DataFrame to database
    df = pd.read_csv(csv_file)
    df.to_sql(table_name, db_base, if_exists="replace", index=False) 
    
def read_data_from_database(cursor, table_name):
    # Execute query
    cursor.execute("SELECT * FROM " + table_name)   
    # Fetch all rows
    rows = cursor.fetchall()
    # Print results
    for row in rows:
        print(row)
    

db_base = connect_to_database(db_file)
read_data_into_database(db_base, csv_file, table_name)   #read csv_file into table with name ship_data and db_base example.db

cursor = db_base.cursor()
read_data_from_database(cursor, table_name)     #read data from a particular table in the database
# Out:
# <sqlite3.Connection object at 0x103a13010>
# (0, 'CAMERON', 'Mr.', 'Charles W.', 38.0, 'Band', 'Crew', 'British', None, None, None, 'Adult', 'Male')
# (1, 'CARR-JONES', 'Mr.', 'E.', 37.0, 'Band', 'Crew', 'British', None, None, None, 'Adult', 'Male')
# (2, 'DRAKEFORD', 'Mr.', 'Edward', 30.0, 'Band', 'Crew', 'British', 'Violin', None, None, 'Adult', 'Male')
# (3, 'HAWKINS', 'Mr.', 'Handel', 25.0, 'Band', 'Crew', 'British', 'Cello', None, None, 'Adult', 'Male')
# (4, 'HEMINGWAY', 'Mr.', 'John William', 27.0, 'Band', 'Crew', 'British', 'Double Bass', None, None, 'Adult', 'Male')
# (5, 'ANDERSON', 'Mr.', 'James Clarke', 48.0, 'Deck', 'Crew', 'British', 'Staff Captain', None, 'Liverpool', 'Adult', 'Male')
# (6, 'ANDERSON', 'Mr.', 'John', None, 'Deck', 'Crew', 'Norwegian', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (7, 'BATTLE', 'Mr.', 'James', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, 'Sligo', 'Adult', 'Male')
# (8, 'BESTIC', 'Mr.', 'Albert Arthur', 24.0, 'Deck', 'Crew', 'British', 'Junior Third Officer', 'Single', 'Dublin', 'Adult', 'Male')
# (9, 'BOWDEN', 'Mr.', 'Joseph ', 19.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (10, 'BROWN', 'Mr.', 'John Manson George', 57.0, 'Deck', 'Crew', 'British', 'Joiner', None, None, 'Adult', 'Male')
# (11, 'CANNON', 'Mr.', 'Robert Henry', 50.0, 'Deck', 'Crew', 'British', 'Inspector', None, None, 'Adult', 'Male')
# (12, 'CLINTON', 'Mr.', 'George', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (13, 'CLYDE', 'Mr.', 'Neil', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (14, 'CRANK', 'Mr.', 'John', None, 'Deck', 'Crew', 'British', 'Baggage Master', None, None, 'Adult', 'Male')
# (15, 'CUNNINGHAM', 'Mr.', 'Edward', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (16, 'DAVIES', 'Mr.', 'John', None, 'Deck', 'Crew', 'British', 'Boatswain', None, None, 'Adult', 'Male')
# (17, 'EGAN', 'Mr.', 'William', None, 'Deck', 'Crew', 'British', "Boatswain's Mate", None, None, 'Adult', 'Male')
# (18, 'ELLIOT', 'Mr.', 'Arthur Graham', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (19, 'ELLIOT', 'Mr.', 'Fred', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (20, 'EVANS', 'Mr.', 'Thomas William', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (21, 'FAYLE', 'Mr.', 'Edward', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (22, 'FLEMMING', 'Mr.', 'Herbert', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (23, 'GARRY', 'Dr.', 'Joseph', 25.0, 'Deck', 'Crew', 'British', 'Assistant Surgeon', None, 'Kildysart', 'Adult', 'Male')
# (24, 'GUNN', 'Mr.', 'C.', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (25, 'HARMAN', 'Mr.', 'John', 56.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, 'Liverpool', 'Adult', 'Male')
# (26, 'HEFFORD', 'Mr.', 'Percy', None, 'Deck', 'Crew', 'British', 'Second Officer', None, None, 'Adult', 'Male')
# (27, 'HEIGHWAY', 'Mr.', 'Edward John', 41.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, 'Strangford', 'Adult', 'Male')
# (28, 'HENNESEY', 'Mr.', 'Frank', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (29, 'HERMAN', 'Mr.', 'Albert', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (30, 'HEYES', 'Mr.', 'J.', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (31, 'HUGHES', 'Mr.', 'John Edward', None, 'Deck', 'Crew', 'British', 'Hospital Attendant', None, None, 'Adult', 'Male')
# (32, 'HUME', 'Mr.', 'James', 19.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, 'Belfast', 'Adult', 'Male')
# (33, 'JOHNSTON', 'Mr.', 'Hugh Robert', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (34, 'JONES', 'Mr.', 'Arthur Rowland', 33.0, 'Deck', 'Crew', 'British', 'First Officer', None, None, 'Adult', 'Male')
# (35, 'JONES', 'Mr.', 'William', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (36, 'KNIGHT', 'Mr.', 'C. T.', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (37, 'LEDENE', 'Mr.', 'Thomas', 50.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', 'Widower', None, 'Adult', 'Male')
# (38, 'LEWIS', 'Mr.', 'John Idwal', 29.0, 'Deck', 'Crew', 'British', 'Senior Third Officer', None, None, 'Adult', 'Male')
# (39, 'LOCKETT', 'Mr.', 'H.', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (40, 'MALONE', 'Mr.', 'F.', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (41, 'McDERMOTT', 'Dr.', 'James Farrell', 38.0, 'Deck', 'Crew', 'British', 'Surgeon', None, 'Liverpool', 'Adult', 'Male')
# (42, 'McGLADE', 'Mr.', 'George', None, 'Deck', 'Crew', 'British', 'Seaman', None, None, 'Adult', 'Male')
# (43, 'McLEOD', 'Mr.', 'Victor', None, 'Deck', 'Crew', 'British', 'O Seaman', None, None, 'Adult', 'Male')
# (44, 'McNALLY', 'Mr.', 'Peter', None, 'Deck', 'Crew', 'British', 'Seaman', None, None, 'Adult', 'Male')
# (45, 'MOORE', 'Mr.', 'Daniel', None, 'Deck', 'Crew', 'British', 'Seaman', None, None, 'Adult', 'Male')
# (46, 'MORTON', 'Mr.', 'Leslie Noel (brother of John)', 18.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', 'Single', None, 'Adult', 'Male')
# (47, 'MORTON', 'Mr.', 'John Clifford (brother of Leslie)', 20.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', 'Single', None, 'Adult', 'Male')
# (48, "O'MAHONEY", 'Mr.', 'Thomas', 21.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (49, "O'NEILL", 'Mr.', 'F. H.', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (50, 'OWENS', 'Mr.', 'Owen', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (51, 'PARRY', 'Mr.', 'Joseph', 26.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (52, 'PIPER', 'Mr.', 'John P.', None, 'Deck', 'Crew', 'British', 'Chief Officer', None, None, 'Adult', 'Male')
# (53, 'QUINN', 'Mr.', "Thomas John (father of Thomas Quinn, bo'sun's boy)", None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', 'Married', None, 'Adult', 'Male')
# (54, 'QUINN', 'Master', 'Thomas (son of Thomas Quinn, AB seaman)', 17.0, 'Deck', 'Crew', 'British', "Boatswain's Boy", 'Single', None, 'Minor', 'Male')
# (55, 'QUIRK', 'Mr.', 'William Eduard', 33.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (56, 'REID', 'Mr.', 'James', None, 'Deck', 'Crew', 'British', 'Seaman', None, None, 'Adult', 'Male')
# (57, 'ROBB', 'Mr.', 'Joseph', 27.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (58, 'ROBERTS', 'Mr.', 'Charles A.', 25.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (59, 'ROBERTSON', 'Mr.', 'Neil', None, 'Deck', 'Crew', 'British', 'Carpenter', None, None, 'Adult', 'Male')
# (60, 'ROBINS', 'Mr.', 'T. (Edward Kyle)', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (61, 'ROPER', 'Mr.', 'John', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (62, 'SEAGRAVES', 'Mr.', 'Patrick', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (63, 'SIKKING', 'Mr.', 'James', 24.0, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (64, 'SIKKING', 'Mr.', 'Florence', None, 'Deck', 'Crew', 'British', "Boatswain's Mate", None, None, 'Adult', 'Male')
# (65, 'SMITH', 'Mr.', 'Peter', None, 'Deck', 'Crew', 'British', 'Master-at-Arms', None, None, 'Adult', 'Male')
# (66, 'STEVENS', 'Mr.', 'John', None, 'Deck', 'Crew', 'British', 'Chief Officer', None, None, 'Adult', 'Male')
# (67, 'THOMPSON', 'Mr.', 'John', None, 'Deck', 'Crew', 'British', 'O Seaman', None, None, 'Adult', 'Male')
# (68, 'THOMPSON', 'Mr.', 'Leo Henry', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (69, 'TODD', 'Mr.', 'James', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (70, 'TURNER', 'Captain', 'William Thomas', 58.0, 'Deck', 'Crew', 'British', 'Captain', 'Separated', 'Liverpool', 'Adult', 'Male')
# (71, 'WILLIAMS', 'Mr.', 'William', None, 'Deck', 'Crew', 'British', 'Master-at-Arms', None, None, 'Adult', 'Male')
# (72, 'YETTS', 'Mr.', 'William R.', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (73, 'YETTS', 'Mr.', 'William R.', None, 'Deck', 'Crew', 'British', 'Able-Bodied Seaman', None, None, 'Adult', 'Male')
# (74, 'ANDERSON', 'Mr.', 'William Affleck', None, 'Engineering', 'Crew', 'British', 'Senior 5th Engineer', None, None, 'Adult', 'Male')
# (75, 'ASHE', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (76, 'BARRETT', 'Mr.', 'Daniel', 18.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (77, 'BARRY', 'Mr.', 'W.', 26.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (78, 'BATT', 'Mr.', 'George', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (79, 'BEATTIE', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (80, 'BEGGS', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Senior 6th Engineer', None, None, 'Adult', 'Male')
# (81, 'BOWEN', 'Mr.', 'Henry', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (82, 'BRADLEY', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (83, 'BREEN', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Leading Fireman', None, None, 'Adult', 'Male')
# (84, 'BRENNAN', 'Mr.', 'Patrick', 47.0, 'Engineering', 'Crew', 'British', 'Greaser', None, 'Liverpool', 'Adult', 'Male')
# (85, 'BRENNAN', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (86, 'BRENNAN', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (87, 'BRIDGE', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (88, 'BROWN', 'Mr.', 'Patrick', 24.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Kilboyne', 'Adult', 'Male')
# (89, 'BROWN', 'Mr.', ' John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (90, 'BROWN', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (91, 'BRYCE', 'Mr.', 'Archie', 54.0, 'Engineering', 'Crew', 'British', 'Chief Engineer', None, None, 'Adult', 'Male')
# (92, 'BURKE', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (93, 'BURNS', 'Mr.', 'John James', None, 'Engineering', 'Crew', 'British', 'Leading Fireman', None, None, 'Adult', 'Male')
# (94, 'BURNS', 'Mr.', 'Joseph', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (95, 'BURNS', 'Mr.', 'Peter', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (96, 'BUTLER', 'Mr.', 'Joseph', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (97, 'CAIN', 'Mr.', 'Thomas', 54.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (98, 'CAMPBELL', 'Mr.', 'Patrick', 35.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Newry', 'Adult', 'Male')
# (99, 'CAMPBELL', 'Mr.', 'Charles', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (100, 'CARRIBINE', 'Mr.', 'Bernard', 43.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (101, 'CARROLL', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Leading Fireman', None, None, 'Adult', 'Male')
# (102, 'CASEY', 'Mr.', 'Patrick', 48.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (103, 'CASEY', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (104, 'CASEY', 'Mr.', 'Joseph', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (105, 'CASSIDY', 'Mr.', 'Bernard', 59.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (106, 'CHADWICK', 'Mr.', 'Jacob', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (107, 'CHESTER', 'Mr.', 'Michael', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (108, 'COADY', 'Mr.', ' James', 53.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (109, 'COCKBURN', 'Mr.', 'Andrew', 44.0, 'Engineering', 'Crew', 'British', 'Senior 2nd Engineer', None, None, 'Adult', 'Male')
# (110, 'COLE', 'Mr.', 'William Henry', None, 'Engineering', 'Crew', 'British', 'Second Intermediate 3rd Engineer', None, None, 'Adult', 'Male')
# (111, 'COLLINS', 'Mr.', 'Patrick', 35.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (112, 'COLLINS', 'Mr.', 'James Lord', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (113, 'COLWELL', 'Mr.', 'William J.', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (114, 'CONLON', 'Mr.', 'Bernard', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (115, 'CONNELLY', 'Mr.', 'Owen', 51.0, 'Engineering', 'Crew', 'British', 'Trimmer', 'Married', 'New York', 'Adult', 'Male')
# (116, 'COONEY', 'Mr.', 'Michael, Jr.', 20.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (117, 'COONEY', 'Mr.', 'Michael, Sr.', 40.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (118, 'CORBOY', 'Mr.', 'Michael', 49.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (119, 'COSTELLO', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (120, 'COYNE (Coyle)', 'Mr.', 'Patrick', 24.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Ballyheane', 'Adult', 'Male')
# (121, 'CROSS', 'Mr.', 'Andrew', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (122, 'CRUMBY', 'Mr.', 'Stephen', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (123, 'CULSHAW', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (124, 'CURRAN', 'Mr.', 'Patrick', 44.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (125, 'CUSHION', 'Mr.', 'Michael', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (126, 'DALEY', 'Mr.', 'Daniel', 42.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Ranelagh', 'Adult', 'Male')
# (127, 'DALYRMPLE', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Refrigeration Greaser', None, None, 'Adult', 'Male')
# (128, 'DAVIES', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (129, 'DAVIES', 'Mr.', 'Mr. J.', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (130, 'DAVIS', 'Mr.', 'Frederick', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (131, 'DELVIN', 'Mr.', 'Henry', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (132, 'DONNELLY', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (133, 'DONNELLY', 'Mr.', 'Peter', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (134, 'DONOGHUE', 'Mr.', 'Peter', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (135, 'DONOVAN', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (136, 'DOUGHERTY (Pitchford)', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (137, 'DOWNEY', 'Mr.', 'Edward', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (138, 'DOYLE', 'Mr.', 'Peter', 32.0, 'Engineering', 'Crew', 'British', 'Leading Fireman', None, 'Liverpool', 'Adult', 'Male')
# (139, 'DOYLE', 'Mr.', 'John', 35.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (140, 'DOYLE', 'Mr.', 'Joseph', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (141, 'DUCKWORTH', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (142, 'DUGGAN', 'Mr.', 'John', 31.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Kirkdale', 'Adult', 'Male')
# (143, 'DUNCAN', 'Mr.', 'Peter Robinson', 31.0, 'Engineering', 'Crew', 'British', 'Senior 4th Engineer', None, None, 'Adult', 'Male')
# (144, 'DUNCAN', 'Mr.', 'Robert Henry', 34.0, 'Engineering', 'Crew', 'British', 'First Senior 3rd Engineer', None, None, 'Adult', 'Male')
# (145, 'DUNCAN', 'Mr.', 'Alexander', None, 'Engineering', 'Crew', 'British', 'Junior 2nd Engineer', None, None, 'Adult', 'Male')
# (146, 'DUNN', 'Mr.', 'Albert Charles', 30.0, 'Engineering', 'Crew', 'British', 'Intermediate 6th Engineer', None, None, 'Adult', 'Male')
# (147, 'DUNN', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (148, 'DWYER', 'Mr.', 'James', 20.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (149, 'DWYER', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (150, 'DYER', 'Mr.', 'John\xa0', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (151, 'EDWARDS', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (152, 'ELLIOTT', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (153, 'ENGLISH', 'Mr.', 'Michael', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (154, 'ENNIS', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (155, 'EVANS', 'Mr.', 'David', None, 'Engineering', 'Crew', 'British', 'Leading Fireman', None, None, 'Adult', 'Male')
# (156, 'EVANS', 'Mr.', 'Robert', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (157, 'FAIRELOUGH', 'Mr.', 'Robert', None, 'Engineering', 'Crew', 'British', 'Donkeyman', None, None, 'Adult', 'Male')
# (158, 'FAIRHURST', 'Mr.', 'Wilfred George', None, 'Engineering', 'Crew', 'British', 'First Intermediate 3rd Engineer', None, None, 'Adult', 'Male')
# (159, 'FARRELL', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (160, 'FARRELL', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (161, 'FEARON', 'Mr.', 'Peter', 30.0, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (162, 'FENTON', 'Mr.', 'Colin Stanley Moorhouse', None, 'Engineering', 'Crew', 'British', 'Deck Engineer', None, None, 'Adult', 'Male')
# (163, 'FERNANDEZ', 'Mr.', 'Eduardo', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (164, 'FIELDS', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (165, 'FINNEGAN', 'Mr.', 'Edward', 22.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (166, 'FitzGERALD', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Electric Attendant', None, 'Liverpool', 'Adult', 'Male')
# (167, 'FORD', 'Mr.', 'John', 45.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (168, 'FORREST', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (169, 'FRENCH', 'Mr.', 'Edward Stanley', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (170, 'GALLAGHER', 'Mr.', 'George', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (171, 'GARDNER', 'Mr.', 'Alfred', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (172, 'GAUL', 'Mr.', 'Richard', None, 'Engineering', 'Crew', 'British', 'Greaser', None, 'Drinagh', 'Adult', 'Male')
# (173, 'GAVAN', 'Mr.', 'Peter', 30.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (174, 'GOODMAN', 'Mr.', 'B.', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (175, 'GOULD', 'Mr.', 'Richard', 34.0, 'Engineering', 'Crew', 'British', 'Senior Boilermaker', None, None, 'Adult', 'Male')
# (176, 'GRANT', 'Mr.', 'Michael', 36.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (177, 'GREGORY', 'Mr.', 'John Henry', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (178, 'GRIFFITHS', 'Mr.', ' William Henry', None, 'Engineering', 'Crew', 'British', 'Refrigeration Greaser', None, None, 'Adult', 'Male')
# (179, 'GRIFFITHS', 'Mr.', 'Samuel Herman', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (180, 'GRUNDY', 'Mr.', 'Mr. George', None, 'Engineering', 'Crew', 'British', 'Leading Fireman', None, None, 'Adult', 'Male')
# (181, 'GUNTHER', 'Mr.', 'Charles', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (182, 'HAMEL', 'Mr.', 'George James', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (183, 'HANLON', 'Mr.', 'Patrick', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (184, 'HARRIS', 'Mr.', 'Edward James', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (185, 'HAYES', 'Mr.', 'John Henry Lamie', 30.0, 'Engineering', 'Crew', 'British', 'Junior 5th Engineer', None, None, 'Adult', 'Male')
# (186, 'HESTON', 'Mr.', 'Patrick', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (187, 'HETHERINGTON', 'Mr.', 'Walter Lewis', None, 'Engineering', 'Crew', 'British', 'Third Senior 3rd Engineer', None, None, 'Adult', 'Male')
# (188, 'HILLHOUSE', 'Mr.', 'Hugh', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (189, 'HODDER', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (190, 'HOEY', 'Mr.', 'James', 25.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Dundalk', 'Adult', 'Male')
# (191, 'HOPKINS', 'Mr.', 'Patrick', 25.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Castlebar', 'Adult', 'Male')
# (192, 'HORDEN', 'Mr.', 'Joseph Thomas', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (193, 'HORNCASTLE', 'Mr.', 'William Alfred', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (194, 'HORRIGAN', 'Mr.', 'Michael', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (195, 'HUGHES', 'Mr.', 'Owen', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (196, 'HUGHES', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (197, 'HUME', 'Mr.', 'Archie', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (198, 'HUSSEY', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (199, 'HUTCHINSON', 'Mr.', 'George', None, 'Engineering', 'Crew', 'British', 'Chief Electrician', None, None, 'Adult', 'Male')
# (200, 'HUTCHINSON', 'Mr.', 'George', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (201, 'JENKINS', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (202, 'JONES', 'Mr.', 'Richard Ellis', 31.0, 'Engineering', 'Crew', 'British', 'Junior 4th Engineer', None, None, 'Adult', 'Male')
# (203, 'JONES', 'Mr.', 'William Ewart Gladstone', 29.0, 'Engineering', 'Crew', 'British', 'Third Electrician', None, None, 'Adult', 'Male')
# (204, 'JONES', 'Mr.', 'Hugh', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (205, 'JONES', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (206, 'JONES', 'Mr.', 'Michael', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (207, 'KEARNEY', 'Mr.', 'Patrick', 25.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Crumlin', 'Adult', 'Male')
# (208, 'KEARNEY', 'Mr.', 'Thomas', 25.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Castlebar', 'Adult', 'Male')
# (209, 'KEATING', 'Mr.', 'Philip', 31.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (210, 'KEEGAN', 'Mr.', 'John Ernest', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (211, 'KEHOE', 'Mr.', 'Denis', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (212, 'KELLY', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (213, 'KELLY', 'Mr.', 'Sidney Crawford', None, 'Engineering', 'Crew', 'British', 'Intermediate 5th Engineer', None, None, 'Adult', 'Male')
# (214, 'KELLY', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (215, 'KENNEDY', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (216, 'KENNEDY', 'Mr.', 'John James', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (217, 'KENNY', 'Mr.', 'Joseph', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (218, 'KEOGH\xa0\xa0\xa0 \xa0', 'Mr.', 'P.\xa0\xa0 \xa0\xa0\xa0 \xa0\xa0\xa0 \xa0\xa0\xa0 \xa0\xa0\xa0 \xa0\xa0\xa0 \xa0', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (219, 'KING', 'Mr.', 'Michael', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (220, 'LAFFEY', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (221, 'LARKIN', 'Mr.', 'James J.', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (222, 'LATHAM', 'Mr.', 'George', None, 'Engineering', 'Crew', 'British', 'Second Electrician', None, None, 'Adult', 'Male')
# (223, 'LAWRENCE', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (224, 'LAWSON', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (225, 'LAWTON', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (226, 'LEA', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Senior 7th Engineer', None, None, 'Adult', 'Male')
# (227, 'LEATHERS', 'Mr.', 'Samuel', None, 'Engineering', 'Crew', 'British', 'Leading Fireman', None, None, 'Adult', 'Male')
# (228, 'LEE', 'Mr.', 'Daniel', 50.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (229, 'LEE', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (230, 'LEECH', 'Mr.', 'T.', None, 'Engineering', 'Crew', 'British', 'First Junior 3rd Engineer', None, None, 'Adult', 'Male')
# (231, 'LEMON', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (232, 'LEWIS', 'Mr.', 'F.', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (233, 'LEWIS', 'Mr.', 'Joseph', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (234, 'LINTON', 'Mr.', 'Isaac', 48.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (235, 'LITTLE', 'Mr.', 'George', None, 'Engineering', 'Crew', 'British', 'Second Senior 3rd Engineer', None, None, 'Adult', 'Male')
# (236, 'LOCKHART', 'Mr.', 'Peter', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (237, 'LOUGHRAN', 'Mr.', 'Patrick', 19.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Newry', 'Adult', 'Male')
# (238, 'LYONS', 'Mr.', 'Archibald', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (239, 'MADDEN', 'Mr.', 'John', 43.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (240, 'MADDEN', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (241, 'MALFIAT', 'Mr.', 'Shef', None, 'Engineering', 'Crew', 'Belgian', 'Trimmer', None, None, 'Adult', 'Male')
# (242, 'MALLIN', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (243, 'MANAN', 'Mr.', ' Andrew', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (244, 'MANNING', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (245, 'MANNING', 'Mr.', 'Peter', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (246, 'MARKEY', 'Mr.', 'Patrick', 30.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Dundalk', 'Adult', 'Male')
# (247, 'MARRION', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (248, 'MARTIN', 'Mr.', 'Albert', None, 'Engineering', 'Crew', 'British', 'Leading Fireman', None, None, 'Adult', 'Male')
# (249, 'McADAM', 'Mr.', 'Michael', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (250, 'McALEAVEY', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (251, 'McALEER', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (252, 'McATEER', 'Mr.', 'Francis', None, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Warrenpoint', 'Adult', 'Male')
# (253, 'McBRIDE', 'Mr.', 'Peter', 52.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Ravensdale', 'Adult', 'Male')
# (254, 'McCABE', 'Mr.', 'Andrew', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (255, 'McCABE', 'Mr.', 'John Alexander', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (256, 'McCABE', 'Mr.', 'Richard', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (257, 'McCANN', 'Mr.', 'Thomas Michael', 22.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (258, 'McCANN', 'Mr.', 'Owen', 30.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Carlingford', 'Adult', 'Male')
# (259, 'McCARTHY', 'Mr.', 'Patrick', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (260, 'McCARTHY', 'Mr.', 'Bartholomew', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (261, 'McCLEAN', 'Mr.', 'Robert', None, 'Engineering', 'Crew', 'British', 'Plumber', None, None, 'Adult', 'Male')
# (262, 'McCORMICK', 'Mr.', 'James', 44.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (263, 'McCUTCHEON', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (264, 'McDERMOTT', 'Mr.', 'Eugene', None, 'Engineering', 'Crew', 'British', 'Trimmer (promoted to Fireman)', None, None, 'Adult', 'Male')
# (265, 'McDERMOTT', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (266, 'McDONALD', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (267, 'McDONALD', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (268, 'McEVOY', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Refrigeration Greaser', None, 'Jonesborough', 'Adult', 'Male')
# (269, 'McGEOUGH', 'Mr.', 'Michael', 30.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Dundalk', 'Adult', 'Male')
# (270, 'McGINTY', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (271, 'McGOWAN', 'Mr.', 'Joseph', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (272, 'McGUGAN', 'Mr.', 'Donald', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (273, 'McGUGAN', 'Mr.', 'Walter', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (274, 'McGUINESS', 'Mr.', 'Bernard', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (275, 'McKENNA', 'Mr.', 'Bernard', 29.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Castlebellingham', 'Adult', 'Male')
# (276, 'McKENNA', 'Mr.', 'Frank', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (277, 'McKENNA', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (278, 'McKENNA', 'Mr.', 'Patrick', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (279, 'McKINDREY', 'Mr.', 'Andrew', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Newry', 'Adult', 'Male')
# (280, 'McLOUGHLIN', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (281, 'McMAHON', 'Mr.', 'Patrick', 37.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (282, 'McMAHON', 'Mr.', 'P.', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (283, 'McNULTY', 'Mr.', 'Peter', 30.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Liverpool', 'Adult', 'Male')
# (284, 'McPARLAND', 'Mr.', 'Terence', 26.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (285, 'McSTAY', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (286, 'MELIA', 'Mr.', 'Patrick', 50.0, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (287, 'MITCHELL', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (288, 'MOLDEN', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (289, 'MORAN', 'Mr.', 'Patrick', None, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Erren', 'Adult', 'Male')
# (290, 'MORAN', 'Mr.', ' James', None, 'Engineering', 'Crew', 'British', 'Greaser', None, 'Erren', 'Adult', 'Male')
# (291, 'MORRICE', 'Mr.', 'David', None, 'Engineering', 'Crew', 'British', 'Junior 6th Engineer', None, None, 'Adult', 'Male')
# (292, 'MORRIS', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (293, 'MURPHY', 'Mr.', 'Dennis', 23.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (294, 'MURPHY', 'Mr.', 'Matthew', 58.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (295, 'MURPHY', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Swords', 'Adult', 'Male')
# (296, 'MYLASKA', 'Mr.', 'C.', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (297, 'MYLES', 'Mr.', 'Peter', 17.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Minor', 'Male')
# (298, 'NEEDHAM', 'Mr.', 'Patrick', 47.0, 'Engineering', 'Crew', 'British', 'Leading Fireman', None, None, 'Adult', 'Male')
# (299, 'NEEDHAM', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (300, 'NEWBY', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (301, 'NORMAN', 'Mr.', 'Arthur William', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (302, 'NORTON', 'Mr.', 'Bernard Patrick', 44.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (303, 'O’BRIEN', 'Mr.', 'Patrick', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (304, 'O’CONNELL', 'Mr.', 'John', 19.0, 'Engineering', 'Crew', 'British', 'Fireman', 'Single', 'Liverpool', 'Adult', 'Male')
# (305, 'O’HARE', 'Mr.', 'Owen', 42.0, 'Engineering', 'Crew', 'British', 'Engineers’ Store', None, None, 'Adult', 'Male')
# (306, 'O’NEILL', 'Mr.', 'Michael', 44.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (307, 'O’NEILL', 'Mr.', 'Bernard', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (308, 'O’NEILL', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (309, 'O’NEILL', 'Mr.', 'Paul', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (310, 'ORANGE', 'Mr.', 'John', 24.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (311, 'ORMROD', 'Mr.', 'Thomas', 40.0, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (312, 'ORMROD', 'Mr.', 'James', 41.0, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (313, 'OSBORNE', 'Mr.', 'J.', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (314, 'OSTERBURG', 'Mr.', 'August', None, 'Engineering', 'Crew', 'Russian', 'Fireman', None, None, 'Adult', 'Male')
# (315, 'OWENS', 'Mr.', 'Richard', None, 'Engineering', 'Crew', 'British', 'Engineering Storekeeper', None, None, 'Adult', 'Male')
# (316, 'PALMER', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (317, 'PATON', 'Mr.', 'J. F. ', None, 'Engineering', 'Crew', 'Brazilian', 'Steering Engineer', None, None, 'Adult', 'Male')
# (318, 'PAYNE', 'Mr.', 'Michael', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (319, 'PIMBLETT', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Refrigeration Greaser', None, None, 'Adult', 'Male')
# (320, 'PLUMMER', 'Mr.', 'Leslie', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (321, 'POWELL', 'Mr.', 'Edward', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (322, 'POWER', 'Mr.', 'Daniel', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (323, 'QUARRIE', 'Mr.', 'Walter Scott', None, 'Engineering', 'Crew', 'British', 'Ventilation Engineer', None, None, 'Adult', 'Male')
# (324, 'QUINN', 'Mr.', 'George', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (325, 'RAFFERTY', 'Mr.', 'Joseph', 23.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (326, 'RAFFERTY', 'Mr.', 'Patrick', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (327, 'RALPH', 'Mr.', 'M.', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (328, 'RATCLIFF', 'Mr.', 'Peter', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (329, 'REYNOLDS', 'Mr.', 'Patrick', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (330, 'RICE', 'Mr.', 'Michael', 60.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (331, 'RICE', 'Mr.', 'Stephen', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (332, 'RIGBY', 'Mr.', 'G.', 24.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (333, 'ROACH(E)', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (334, 'ROBINSON', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (335, 'ROGAN', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (336, 'ROSS', 'Mr.', 'E. W.', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (337, 'ROSSITER', 'Mr.', 'Laurence', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (338, 'ROWAN', 'Mr.', 'Fred', 44.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (339, 'ROWE', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (340, 'RUDDAN', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (341, 'RYAN (Rice)', 'Mr.', 'Edward', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (342, 'SAVAGE', 'Mr.', 'Frank', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (343, 'SCANNELL', 'Mr.', 'Charles', 25.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Roberts Cove  Minane Bridge', 'Adult', 'Male')
# (344, 'SCOTT', 'Mr.', 'C.', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (345, 'SHARKEY', 'Mr.', 'John\xa0\xa0 \xa0', None, 'Engineering', 'Crew', 'British', 'Electric Attendant', None, None, 'Adult', 'Male')
# (346, 'SHEPHERD', 'Mr.', 'Ralph Alfred', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (347, 'SHERIDAN', 'Mr.', 'Geoffrey', 50.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (348, 'SHERIDAN', 'Mr.', 'Patrick', 56.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (349, 'SINNOT', 'Mr.', 'William', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (350, 'SLAVIN', 'Mr.', 'Owen', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, 'Dundalk', 'Adult', 'Male')
# (351, 'SMITH', 'Mr.', 'William Thomas', None, 'Engineering', 'Crew', 'British', 'Intermediate 2nd Engineer', None, None, 'Adult', 'Male')
# (352, 'SOUTHWOLD', 'Mr.', 'Henry', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (353, 'STAFFORD', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (354, 'STANLEY', 'Mr.', 'H.', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (355, 'STANLEY (Shanley?)', 'Mr.', 'J.', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (356, 'SWEENEY', 'Mr.', 'Jeremiah', None, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Castlebar', 'Adult', 'Male')
# (357, 'TAYLOR', 'Mr.', 'Chris', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (358, 'TAYLOR', 'Mr.', 'Thomas', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (359, 'TEAR', 'Mr.', 'Joseph Edward', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (360, 'THOMPSON', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (361, 'THOMPSON', 'Mr.', 'John E.', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (362, 'THOMPSON', 'Mr.', 'Michael', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (363, 'TIERNEY', 'Mr.', 'Michael', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (364, 'TONER (Tower)', 'Mr.', 'Francis "Frank"', None, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (365, 'TOOLE', 'Mr.', 'James', 38.0, 'Engineering', 'Crew', 'British', 'Fireman', None, 'Liverpool', 'Adult', 'Male')
# (366, 'TRAINOR', 'Mr.', 'A. (Thomas Pilcher)', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (367, 'TRAYNOR', 'Mr.', 'Philip Henry', 28.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (368, 'TURNER', 'Mr.', 'Joseph', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (369, 'VOSE', 'Mr.', 'George', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (370, 'WALSH', 'Mr.', 'R.', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (371, 'WARD', 'Mr.', 'Michael', 28.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (372, 'WARD', 'Mr.', 'John', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (373, 'WAREING', 'Mr.', 'Richard', 52.0, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (374, 'WEBB', 'Mr.', 'James', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (375, 'WELSH', 'Mr.', 'Christopher', 28.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (376, 'WELSH', 'Mr.', 'Martin', 36.0, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (377, 'WHEELHOUSE', 'Mr.', 'Alfred Faulkner', None, 'Engineering', 'Crew', 'British', 'Junior 7th Engineer', None, None, 'Adult', 'Male')
# (378, 'WHELAN', 'Mr.', 'John James', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (379, 'WHITMORE', 'Mr.', 'George', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (380, 'WIENCKE', 'Mr.', 'Paul Frederick (Friedriche)', 38.0, 'Engineering', 'Crew', 'German', 'Trimmer', 'Married', 'Liverpool', 'Adult', 'Male')
# (381, 'WIENCKE', 'Master', 'Paul', 16.0, 'Engineering', 'Crew', 'British', 'Greaser', None, 'Liverpool', 'Minor', 'Male')
# (382, 'WILLIAMS', 'Mr.', 'Sydney', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (383, 'WOOD', 'Mr.', 'John H.', None, 'Engineering', 'Crew', 'British', 'Greaser', None, None, 'Adult', 'Male')
# (384, 'WOODS', 'Mr.', 'Joseph', None, 'Engineering', 'Crew', 'British', 'Fireman', None, None, 'Adult', 'Male')
# (385, 'WYLIE', 'Mr.', 'Richard G.', 31.0, 'Engineering', 'Crew', 'British', 'Third Junior 3rd Engineer', None, None, 'Adult', 'Male')
# (386, 'WYNN', 'Mr.', 'Peter', None, 'Engineering', 'Crew', 'British', 'Trimmer', None, None, 'Adult', 'Male')
# (387, 'ADAMS', 'Mr.', 'William McMillan', 19.0, 'Saloon', 'Passenger', 'USA', None, 'Single', 'Cambridge', 'Adult', 'Male')
# (388, 'ADAMS', 'Mr.', 'Arthur Henry', 46.0, 'Saloon', 'Passenger', 'USA', None, 'Married', 'London', 'Adult', 'Male')
# (389, 'ADAMS', 'Mr.', 'Henry', 58.0, 'Saloon', 'Passenger', 'British', None, 'Married', 'Tenby', 'Adult', 'Male')
# (390, 'ADAMS', 'Mrs.', 'Henry (Annie Elizabeth Macnutt)', 46.0, 'Saloon', 'Passenger', 'British', None, 'Married', 'Boston    ', 'Adult', 'Female')
# (391, 'ALLAN', 'Lady', 'Hugh Montagu (Marguerite Ethel MacKenzie)', 42.0, 'Saloon', 'Passenger', 'British', None, 'Married', 'Montreal', 'Adult', 'Female')
# (392, 'ALLAN', 'Miss', 'Gwendolyn Evelyn', 15.0, 'Saloon', 'Passenger', 'British', None, 'Single', 'Montreal', 'Minor', 'Female')
# (393, 'ALLAN', 'Miss', 'Anna Marjory', 16.0, 'Saloon', 'Passenger', 'British', None, 'Single', 'Montreal', 'Minor', 'Female')
# (394, 'ALLEN', 'Miss', 'Dorothy Ditman (nurse to the Cromptons)', 26.0, 'Saloon', 'Passenger', 'USA', None, 'Single', 'Philadephia', 'Adult', 'Female')
# (395, 'ALLES', 'Mr.', 'Nicholas Naftel', 50.0, 'Saloon', 'Passenger', 'USA', None, None, 'New York', 'Adult', 'Male')
# (396, 'AYALA', 'Mr.', 'Julian de', 45.0, 'Saloon', 'Passenger', 'Cuban', None, 'Married', 'Liverpool', 'Adult', 'Male')
# (397, 'BAKER', 'Mr.', 'James', 50.0, 'Saloon', 'Passenger', 'British', None, None, None, 'Adult', 'Male')
# (398, 'BAKER', 'Miss', 'Amelia "Millie" Anne', 27.0, 'Saloon', 'Passenger', 'USA', None, 'Divorced', 'New York', 'Adult', 'Female')
# (399, 'BALDWIN', 'Mr.', 'Harry Bradley', 48.0, 'Saloon', 'Passenger', 'USA', None, 'Married', 'New York', 'Adult', 'Male')
# (400, 'BALDWIN', 'Mrs.', 'Harry Bradley (Mary Margaret MacCauley)', 38.0, 'Saloon', 'Passenger', 'USA', None, 'Married', 'New York', 'Adult', 'Female')
# (401, 'BARNES', 'Mr.', 'Allen Byron', 43.0, 'Saloon', 'Passenger', 'British', None, None, 'Berlin', 'Adult', 'Male')
# (402, 'BARTLETT', 'Mr.', 'George Walter Bowers', 42.0, 'Saloon', 'Passenger', 'British', None, 'Married', 'London', 'Adult', 'Male')
# (403, 'BARTLETT', 'Mrs.', 'George W. B. (Irma Florine Rothschild)', 31.0, 'Saloon', 'Passenger', 'British', None, 'Married', 'London', 'Adult', 'Female')
# (404, 'BATES', 'Mr.', 'Lindon Wallace, Jr.', 32.0, 'Saloon', 'Passenger', 'USA', None, 'Single', 'New York', 'Adult', 'Male')
# (405, 'BATTERSBY', 'Mr.', 'James Johnson', 40.0, 'Saloon', 'Passenger', 'British', None, None, 'Stockport', 'Adult', 'Male')
# ...
# (1834, 'MacKENZIE', 'Mr.', 'Henry', None, 'Victualling', 'Crew', 'British', 'Waiter', None, None, 'Adult', 'Male')
# (1835, 'MacKENZIE (McKENZIE?)', 'Mr.', 'Kenneth ', 22.0, 'Victualling', 'Crew', 'British', 'Waiter', None, 'Belfast', 'Adult', 'Male')
# (1836, 'MacPHERSON', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'Waiter', None, None, 'Adult', 'Male')
# (1837, 'MARSHALL', 'Mr.', 'James', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1838, 'MATTHEWS', 'Mr.', 'Henry', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1839, 'MAYLOR', 'Mr.', 'George', None, 'Victualling', 'Crew', 'British', 'Boots Steward', None, None, 'Adult', 'Male')
# (1840, 'McALTEER', 'Mr.', 'Matthew', None, 'Victualling', 'Crew', 'British', 'Vegetable Cook', None, None, 'Adult', 'Male')
# (1841, 'McARTHUR', 'Mr.', 'William George', None, 'Victualling', 'Crew', 'British', 'Assistant Cook', None, None, 'Adult', 'Male')
# (1842, 'McCLELLAND', 'Mr.', 'David', None, 'Victualling', 'Crew', 'British', 'Extra Extra Second Cook', None, None, 'Adult', 'Male')
# (1843, 'McCLEOD', 'Mr.', 'William', None, 'Victualling', 'Crew', 'British', 'Saloon Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1844, 'McCONKEY', 'Mr.', 'Christopher Evans', 42.0, 'Victualling', 'Crew', 'British', 'Second Waiter', None, 'Liverpool  Ambrose Grove ', 'Adult', 'Male')
# (1845, 'McCORMACK', 'Mr.', 'Donald', None, 'Victualling', 'Crew', 'British', 'Assistant Telegraphist', None, None, 'Adult', 'Male')
# (1846, 'McCORMACK', 'Miss', 'Margarita Christina ', 34.0, 'Victualling', 'Crew', 'British', 'Stewardess', None, None, 'Adult', 'Female')
# (1847, 'McCUBBIN', 'Mr.', 'James Alexander', 62.0, 'Victualling', 'Crew', 'British', 'Purser', 'Widowed', 'Liverpool', 'Adult', 'Male')
# (1848, 'McDONALD', 'Mr.', 'Charles', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1849, 'McFARLANE', 'Mr.', 'Malcolm John', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1850, 'McGREGOR', 'Miss', 'Agnes', 43.0, 'Victualling', 'Crew', 'British', 'Stewardess', None, None, 'Adult', 'Female')
# (1851, 'McIVER', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'Assistant Steward (Waiter)', None, None, 'Adult', 'Male')
# (1852, 'McKENZIE', 'Mr.', 'Henry', None, 'Victualling', 'Crew', 'British', 'Night Watchman', None, None, 'Adult', 'Male')
# (1853, 'McLAUGLIN', 'Mr.', 'Joseph', None, 'Victualling', 'Crew', 'British', 'Sculleryman', None, None, 'Adult', 'Male')
# (1854, 'McSANE', 'Mr.', 'Patrick', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1855, 'MILLS', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1856, 'MITCHELL', 'Mr.', 'George', None, 'Victualling', 'Crew', 'British', "Ship's Printer", None, None, 'Adult', 'Male')
# (1857, 'MITCHELL', 'Mr.', 'William', None, 'Victualling', 'Crew', 'British', 'Second Linenkeeper', None, None, 'Adult', 'Male')
# (1858, 'MOFFATT', 'Mr.', 'John Herbertson Bernstone Hyman', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1859, 'MORECROFT', 'Mrs.', 'Herbert (Fannie Jane Chamberlain)', 43.0, 'Victualling', 'Crew', 'British', 'Stewardess', None, None, 'Adult', 'Female')
# (1860, 'MORROW', 'Miss', 'Harding', 42.0, 'Victualling', 'Crew', 'British', 'Stewardess', None, None, 'Adult', 'Female')
# (1861, 'MORSE', 'Mr.', 'Robert', 40.0, 'Victualling', 'Crew', 'British', 'Saloon Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1862, 'MOSS', 'Mr.', 'John Barrow', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1863, 'MUDGE', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'Night Watchman', None, None, 'Adult', 'Male')
# (1864, 'MURPHY', 'Mr.', 'John Henry', 32.0, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1865, 'NEEMS', 'Mr.', 'William Francis', 37.0, 'Victualling', 'Crew', 'British', 'First Waiter', 'Married', 'New Brighton', 'Adult', 'Male')
# (1866, 'NEWBOLD', 'Mr.', 'Hubert H.', None, 'Victualling', 'Crew', 'British', 'Cellarman', None, None, 'Adult', 'Male')
# (1867, 'NEWPORT', 'Mr.', 'William', None, 'Victualling', 'Crew', 'British', 'Smokeroom Steward', None, None, 'Adult', 'Male')
# (1868, 'NICE', 'Mr.', 'Reginald Bertie S.\xa0', None, 'Victualling', 'Crew', 'British', 'Barber', None, None, 'Adult', 'Male')
# (1869, 'NIEMANN', 'Mr.', 'Robert', None, 'Victualling', 'Crew', 'British', 'Waiter', None, None, 'Adult', 'Male')
# (1870, 'NIXON', 'Mr.', 'Harold', None, 'Victualling', 'Crew', 'British', 'Storekeeper', None, None, 'Adult', 'Male')
# (1871, 'NUSSBAUM', 'Mr.', 'Samuel', None, 'Victualling', 'Crew', 'Swiss', 'Soup Cook', None, None, 'Adult', 'Male')
# (1872, 'ORWIN', 'Mr.', 'Nicholas', None, 'Victualling', 'Crew', 'British', 'Deck Steward, Second Cabin', None, None, 'Adult', 'Male')
# (1873, 'OSTERMAN', 'Mr.', 'Jacob', None, 'Victualling', 'Crew', 'British', 'Waiter', None, None, 'Adult', 'Male')
# (1874, 'OTTINO', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'Larder Cook', None, None, 'Adult', 'Male')
# (1875, 'OWEN', 'Mr.', 'Thomas', None, 'Victualling', 'Crew', 'British', 'Linenkeeper', None, None, 'Adult', 'Male')
# (1876, 'PARRY', 'Mr.', 'Frank', 45.0, 'Victualling', 'Crew', 'British', 'Assistant Deck Steward', None, None, 'Adult', 'Male')
# (1877, 'PEDERSON', 'Mr.', 'Johan Adolph\xa0', None, 'Victualling', 'Crew', 'British', 'Interpreter', None, None, 'Adult', 'Male')
# (1878, 'PENKEYMAN', 'Mr.', 'Samuel J.', None, 'Victualling', 'Crew', 'British', 'Pantry Steward', None, None, 'Adult', 'Male')
# (1879, 'PENNY', 'Mr.', 'Algernon Percy', 33.0, 'Victualling', 'Crew', 'British', 'Saloon Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1880, 'PERRY', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'Saloon Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1881, 'PHILLIPS', 'Miss', 'Mary', 33.0, 'Victualling', 'Crew', 'British', 'Stewardess', None, None, 'Adult', 'Female')
# (1882, 'PINKERTON', 'Mr.', 'Robert', None, 'Victualling', 'Crew', 'British', 'Chief Baker', None, 'Liverpool', 'Adult', 'Male')
# (1883, 'POTTER', 'Mr.', 'Benjamin', None, 'Victualling', 'Crew', 'British', 'Waiter', None, None, 'Adult', 'Male')
# (1884, 'PRATT', 'Mr.', 'Richard', None, 'Victualling', 'Crew', 'British', 'Grill Cook', None, None, 'Adult', 'Male')
# (1885, 'PRICE', 'Mr.', 'C.', None, 'Victualling', 'Crew', 'British', 'Waiter', None, None, 'Adult', 'Male')
# (1886, 'PRINGLE', 'Mr.', 'Thomas', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1887, 'PROWSE', 'Mr.', 'Thomas', None, 'Victualling', 'Crew', 'British', 'Assistant Pantry Steward', None, None, 'Adult', 'Male')
# (1888, 'QUINN', 'Mr.', 'Alfred', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1889, 'RANDALL', 'Mr.', 'Charles', 53.0, 'Victualling', 'Crew', 'British', 'Saloon Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1890, 'REDMOND', 'Mr.', 'James', None, 'Victualling', 'Crew', 'British', 'Vegetable Cook', None, None, 'Adult', 'Male')
# (1891, 'REID', 'Mr.', 'Alfred', None, 'Victualling', 'Crew', 'British', 'Third Waiter', None, None, 'Adult', 'Male')
# (1892, 'RICHARDSON', 'Miss', 'Annie', 37.0, 'Victualling', 'Crew', 'British', 'Stewardess', None, None, 'Adult', 'Female')
# (1893, 'RISTON', 'Mr.', 'Issac', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1894, 'ROACH', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1895, 'ROBERTS', 'Mr.', 'John', 19.0, 'Victualling', 'Crew', 'British', "Assistant Engineers' Mess Steward", None, None, 'Adult', 'Male')
# (1896, 'ROBERTS', 'Miss', 'Annie Jane', 35.0, 'Victualling', 'Crew', 'British', 'Stewardess', None, None, 'Adult', 'Female')
# (1897, 'RONNAN', 'Mr.', 'George', 16.0, 'Victualling', 'Crew', 'British', 'Assistant Butcher', None, None, 'Minor', 'Male')
# (1898, 'ROSE', 'Mr.', 'William', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1899, 'ROSS', 'Mr.', 'Henry', None, 'Victualling', 'Crew', 'British', 'Barkeeper', None, None, 'Adult', 'Male')
# (1900, 'ROURKE', 'Mr.', 'Stanley', 21.0, 'Victualling', 'Crew', 'British', 'Lift Attendant', None, None, 'Adult', 'Male')
# (1901, 'ROWBOTHAM', 'Mr.', 'Harold E.\xa0', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1902, 'RUFFELS', 'Mr.', 'William Samuel', None, 'Victualling', 'Crew', 'British', 'Saloon Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1903, 'RUSHTON', 'Mr.', 'George', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1904, 'RUSSELL', 'Mr.', 'Frederick', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1905, 'RYLANDS', 'Mr.', 'William Deakin', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1906, 'SAULTRY', 'Mr.', 'William', None, 'Victualling', 'Crew', 'British', "Ship's Cook", None, None, 'Adult', 'Male')
# (1907, 'SCANTLEBURY', 'Mr.', 'Samuel', None, 'Victualling', 'Crew', 'British', 'Sculleryman', None, None, 'Adult', 'Male')
# (1908, 'SEPHTON', 'Mr.', 'William', None, 'Victualling', 'Crew', 'British', "Night Fireman's Cook", None, None, 'Adult', 'Male')
# (1909, 'SETTLE', 'Mr.', 'Vincent', 55.0, 'Victualling', 'Crew', 'British', 'Saloon Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1910, 'SEURRE', 'Mr.', 'Etienne Pierre', None, 'Victualling', 'Crew', 'French', 'Chef', None, None, 'Adult', 'Male')
# (1911, 'SHANN', 'Mr.', 'Sydney James', None, 'Victualling', 'Crew', 'British', 'Third Waiter', None, None, 'Adult', 'Male')
# (1912, 'SHARP', 'Master', 'Philip Archibald', None, 'Victualling', 'Crew', 'British', "Steward's Boy", None, None, 'Minor', 'Male')
# (1913, 'SHAVLEY', 'Mr.', 'Gerald', None, 'Victualling', 'Crew', 'British', 'Waiter', None, None, 'Adult', 'Male')
# (1914, 'SHEIL', 'Mr.', 'Michael S.', 32.0, 'Victualling', 'Crew', 'British', 'Saloon Steward', None, None, 'Adult', 'Male')
# (1915, 'SHEVLAND', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1916, 'SIMPSON', 'Mr.', 'Malcolm', 34.0, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1917, 'SKAY', 'Master', 'Edward', 16.0, 'Victualling', 'Crew', 'British', 'Kitchen Porter', None, None, 'Minor', 'Male')
# (1918, 'SLOANE', 'Mr.', 'Leonard Hanson', None, 'Victualling', 'Crew', 'British', 'Junior Assistant Purser', None, None, 'Adult', 'Male')
# (1919, 'SMITH', 'Mr.', 'Oliver Barrow', None, 'Victualling', 'Crew', 'British', "Ship's Cook", None, None, 'Adult', 'Male')
# (1920, 'SMITH', 'Mr.', 'William', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1921, 'SPENDLEY', 'Mr.', 'David March', None, 'Victualling', 'Crew', 'British', 'Waiter', None, None, 'Adult', 'Male')
# (1922, 'STANLEY', 'Mr.', 'David H.', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1923, 'STANSFIELD', 'Mr.', 'Leslie', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1924, 'STARK', 'Mr.', 'Robert Lucas', None, 'Victualling', 'Crew', 'British', 'Second Cabin Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1925, 'STEINBERG', 'Master', 'Arthur Valentine', None, 'Victualling', 'Crew', 'British', "Steward's Boy", None, None, 'Minor', 'Male')
# (1926, 'STEWART', 'Mr.', 'Thomas Edgar', 23.0, 'Victualling', 'Crew', 'British', 'Assistant Steward', None, None, 'Adult', 'Male')
# (1927, 'STRINGER', 'Mr.', 'Harry', 26.0, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1928, 'SUTTAN', 'Mr.', 'Nugent Moore', None, 'Victualling', 'Crew', 'British', 'Pantry Steward', None, None, 'Adult', 'Male')
# (1929, 'SUTTON', 'Mr.', 'Frank', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1930, 'SWIFT', 'Mr.', 'Edward', None, 'Victualling', 'Crew', 'British', 'Third Cook', None, None, 'Adult', 'Male')
# (1931, 'THOMAS', 'Mr.', 'William Stanford', 44.0, 'Victualling', 'Crew', 'British', 'Second Cabin Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1932, 'THOMAS', 'Mr.', 'George Henry', None, 'Victualling', 'Crew', 'British', "Assistant Officers' Mess Steward", None, None, 'Adult', 'Male')
# (1933, 'THOMAS', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1934, 'THORN', 'Mr.', 'Alfred Richard', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1935, 'THORNLEY', 'Mr.', 'George', None, 'Victualling', 'Crew', 'British', 'Assistant Pantry Steward', None, None, 'Adult', 'Male')
# (1936, 'ULGAR', 'Mr.', 'Jean', None, 'Victualling', 'Crew', 'Spanish', 'Sauce Cook', None, None, 'Adult', 'Male')
# (1937, 'Van HOECK', 'Mr.', 'Julius E. ', 27.0, 'Victualling', 'Crew', 'Dutch', 'First Waiter', None, None, 'Adult', 'Male')
# (1938, 'VARNEY', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'Waiter', None, None, 'Adult', 'Male')
# (1939, 'VERDIN', 'Mr.', 'Francis', None, 'Victualling', 'Crew', 'British', 'Sculleryman', None, None, 'Adult', 'Male')
# (1940, 'WALLACE', 'Mr.', 'James', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1941, 'WEIGH', 'Mr.', 'Edward\xa0', None, 'Victualling', 'Crew', 'British', 'Waiter', None, None, 'Adult', 'Male')
# (1942, 'WEIR', 'Mrs.', 'Margaret', 51.0, 'Victualling', 'Crew', 'British', 'Stewardess', None, None, 'Adult', 'Female')
# (1943, 'WHALLEY', 'Mr.', 'Leslie', None, 'Victualling', 'Crew', 'British', 'Third Waiter', None, None, 'Adult', 'Male')
# (1944, 'WIGGINS', 'Mr.', 'William', 23.0, 'Victualling', 'Crew', 'British', 'Deck Steward', None, None, 'Adult', 'Male')
# (1945, 'WILKINSON', 'Mr.', 'Mr. James', None, 'Victualling', 'Crew', 'British', 'Engineers’ Mess Steward', None, None, 'Adult', 'Male')
# (1946, 'WILLIAMS', 'Mr.', 'John', None, 'Victualling', 'Crew', 'British', 'Third Waiter', None, None, 'Adult', 'Male')
# (1947, 'WILLIAMS', 'Mr.', 'Mr. Harold', None, 'Victualling', 'Crew', 'British', 'Second Waiter', None, None, 'Adult', 'Male')
# (1948, 'WILLIAMS', 'Mr.', 'Robert', None, 'Victualling', 'Crew', 'British', 'Night Watchman', None, None, 'Adult', 'Male')
# (1949, 'WILLIAMS', 'Mr.', 'Robert Neptune', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1950, 'WILLIAMS', 'Mr.', 'William H.', None, 'Victualling', 'Crew', 'British', 'Saloon Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1951, 'WILMIN', 'Mr.', 'William', None, 'Victualling', 'Crew', 'British', 'Pantry Steward', None, None, 'Adult', 'Male')
# (1952, 'WILSON', 'Mr.', 'Robert', None, 'Victualling', 'Crew', 'British', 'First Waiter', None, None, 'Adult', 'Male')
# (1953, 'WISEMAN', 'Mr.', 'James', None, 'Victualling', 'Crew', 'British', 'Second Baker', None, None, 'Adult', 'Male')
# (1954, 'WOOD', 'Mr.', 'Walter', 31.0, 'Victualling', 'Crew', 'British', 'Saloon Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1955, 'WOOD', 'Mr.', 'Henry Edward', 35.0, 'Victualling', 'Crew', 'British', 'Assistant Pantry Steward', None, None, 'Adult', 'Male')
# (1956, 'WOOD', 'Mr.', 'Alfred', None, 'Victualling', 'Crew', 'British', 'Saloon Cabin Bed Steward', None, None, 'Adult', 'Male')
# (1957, 'WOOD', 'Mr.', 'Wallace Edkin', None, 'Victualling', 'Crew', 'British', 'Barkeeper, Smokeroom Second Cabin', None, None, 'Adult', 'Male')
# (1958, 'WRIGHT', 'Master', 'Harold Joseph', None, 'Victualling', 'Crew', 'British', "Steward's Boy", None, None, 'Minor', 'Male')
# (1959, 'WYNNE', 'Master', 'George', 16.0, 'Victualling', 'Crew', 'British', 'Assistant Cook', None, 'Liverpool', 'Minor', 'Male')
# (1960, 'WYNNE', 'Mr.', 'Joseph Dominic', 37.0, 'Victualling', 'Crew', 'British', 'Sculleryman', None, 'Liverpool', 'Adult', 'Male')

# %%
# 3. Connecting Tkinter with SQL code for reading data from tables.

import tkinter as tk
from tkinter import ttk
import sqlite3

db_file = "example.db"
tree = ""

# -------------------------------------------------
# FUNCTION TO READ DATA AND DISPLAY IN TREEVIEW
# -------------------------------------------------
def read_data_from_database_to_form(cursor, table_name):
    """
    Executes a SELECT query on the specified table
    and displays the results in the Tkinter Treeview.
    """
    try:
        # Execute query
        cursor.execute(f"SELECT * FROM  {table_name}")   
        
        # Fetch all rows returned by the query
        rows = cursor.fetchall()
        
        # Get column names from the query result
        columns = [description[0] for description in cursor.description]
        
        # Debug print (helps confirm data is returned)
        print("Rows returned:", len(rows))

        # Clear any existing rows from the Treeview
        for item in tree.get_children():
            tree.delete(item)
        
        # Configure Treeview columns
        tree["columns"] = columns
        tree["show"] = "headings"

        # Create column headings dynamically
        for col in columns:
            tree.heading(col, text=col)
            tree.column(col, width=120)

        # Insert each row into the Treeview
        for row in rows:
            tree.insert("", tk.END, values=row)

    except Exception as e:
        # Print any errors that occur
        print("Error:", e)
    
    # Print results for debugging
    #for row in rows:
    #    print(row)
        

# -------------------------------------------------
# GUI SETUP
# -------------------------------------------------

# Create main application window
root = tk.Tk()
root.title("Database Query Viewer")
root.geometry("800x400")

# Button to load data
load_button = tk.Button(root, text="Load Data", command=lambda: read_data_from_database_to_form(cursor, table_name))
load_button.pack(pady=10)

# Frame for table and scrollbar
frame = tk.Frame(root)
frame.pack(fill="both", expand=True)

# Create vertical and horizontal scrollbars
scroll_y = tk.Scrollbar(frame, orient="vertical")
scroll_x = tk.Scrollbar(frame, orient="horizontal")

# Create Treeview widget (table display)
tree = ttk.Treeview(
    frame,
    yscrollcommand=scroll_y.set,
    xscrollcommand=scroll_x.set
)

# Connect scrollbars to Treeview
scroll_y.config(command=tree.yview)
scroll_x.config(command=tree.xview)

# Pack scrollbars and table into frame
scroll_y.pack(side="right", fill="y")
scroll_x.pack(side="bottom", fill="x")
tree.pack(fill="both", expand=True)

# -------------------------------------------------
# START GUI EVENT LOOP
# -------------------------------------------------
root.mainloop()

# Close connection
db_base.close()
# Out:
# Rows returned: 1961
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import sqlite3

conn = sqlite3.connect("example.db")

cursor = conn.cursor()

create_table_sql = """CREATE TABLE IF NOT EXISTS passengers (
passenger_id INTEGER PRIMARY KEY,
first_name TEXT NOT NULL,
last_name TEXT NOT NULL,
age INTEGER,
nationality TEXT
);
"""

cursor.execute(create_table_sql)

conn.commit()

conn.close()

print("Table created successfully")
# Out:
# Table created successfully
