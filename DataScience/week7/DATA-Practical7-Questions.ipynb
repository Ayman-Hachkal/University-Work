# %% [markdown]
# # DATA Practical 7 - Questions
#
# Simos Gerasimou
#
#
# ## A Data Journey Through The Titanic
#
# On April 15, 1912, during her maiden voyage from Southampton to New York, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg ([Wikipedia](https://en.wikipedia.org/wiki/RMS_Titanic)). As it was considered “unsinkable”, the Titanic did not carry enough lifeboats for everyone onboard, resulting in the death of 1502 out of 2224 passengers and crew.
#
# **DataVision** has been commissioned by His Majesty The King to investigate the conditions in which people survived and whether this was because of luck or whether some groups were more likely to survive than others. If discrimination due to gender or socio-economic class is identified, the Queen intends to use this information to change the cruise policies accordinly.
#
# #### Your tasks are to explore this dataset and generade some actionable knowledge.
#
#
# #### This Jupyter Notebook will be presented to  the House of Commons  who have limited knowledge about data science. So, your findings should be complemented by a suitable justification explaining what you observe and, when applicable, what does this observation  mean and, possibly, why it occurs.
#
# * For each question (task) a description is provided accompanied (most of the time) by two cells: one for writing the Python code and another for providing the justification. Feel free to add more cells if you feel they are needed, but keep the cells corresponding to the same question close by.
#
# #### Note: You are advised to use Pandas. For the visualisation, you can use Pandas, Matplotlib or Seaborn.
#
# To answer these exercises, you should first read:
#
# (1) Read **Chapter 3: Data Manipulation with Pandas from the Python Data Science Handbook** (https://jakevdp.github.io/PythonDataScienceHandbook/03.00-introduction-to-pandas.html)
#
# (2) Read **Chapter 4: Visualization with Matplotlib**
# (https://jakevdp.github.io/PythonDataScienceHandbook/04.00-introduction-to-matplotlib.html)
#
#
# **Numpy API Reference**: https://numpy.org/doc/stable/reference
#
# **Pandas API Reference**:  https://pandas.pydata.org/pandas-docs/stable/reference/index.html
#
# **Matplotlib API Reference**: https://matplotlib.org/stable/api/index
#
# **Seaborn API Reference**: https://seaborn.pydata.org/api.html
#
# ***

# %% [markdown]
# ### Part 1: Reading dataset
#
#
# The Titanic dataset is available on VLE (look for titanicFull.csv in the Practicals section)
#
# Before doing the tasks below, you may want to explore the dataset using a spreadsheet editor (e.g., Excel) to get a high-level view of the dataset.
#
# **T1) Load the Titanic dataset using Pandas**
#
# **Note**: You have to download the dataset on your local machine and then load it onto the Jupyter Notebook

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

file = "titanicFull.csv"
df = pd.read_csv(file)

# %% [markdown]
# ***
#
# ### Part 2: Cleaning the dataset
#
# **T2i) Print the first 4 records of the dataset**

# %%
#Write your answer here

df.head(4)
# Out:
#    pclass  survived                                  name     sex    age  \
# 0       1         1         Allen, Miss. Elisabeth Walton  female  29.00
# 1       1         1        Allison, Master. Hudson Trevor    male   0.92
# 2       1         0          Allison, Miss. Helen Loraine  female   2.00
# 3       1         0  Allison, Mr. Hudson Joshua Creighton    male  30.00
#
#    sibsp  parch  ticket      fare    cabin embarked
# 0      0      0   24160  211.3375       B5        S
# 1      1      2  113781  151.5500  C22 C26        S
# 2      1      2  113781  151.5500  C22 C26        S
# 3      1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# **T2ii) Print the last 6 records of the dataset**

# %%
#Write your answer here
df.tail(6)
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1303       3         0      Yousseff, Mr. Gerious    male   NaN      0      0
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked
# 1303    2627  14.4583   NaN        C
# 1304    2665  14.4542   NaN        C
# 1305    2665  14.4542   NaN        C
# 1306    2656   7.2250   NaN        C
# 1307    2670   7.2250   NaN        C
# 1308  315082   7.8750   NaN        S

# %% [markdown]
# **T3) Get general info about the dataset**

# %%
#Write your answer here
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   int64
#  2   name      1309 non-null   str
#  3   sex       1309 non-null   str
#  4   age       1046 non-null   float64
#  5   sibsp     1309 non-null   int64
#  6   parch     1309 non-null   int64
#  7   ticket    1309 non-null   str
#  8   fare      1308 non-null   float64
#  9   cabin     295 non-null    str
#  10  embarked  1307 non-null   str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 112.6 KB

# %% [markdown]
# **T4) Explore the dataset and try to understand the meaning of each variable (column). Identify which variables are categorical and which are numerical.**
#
# **Note**: Inferring the meaning of variables 'Pclass', 'SibSp', 'Parch' could be challenging; think of what is missing from the dataset and what types of people were travelling on the Titanic. If you find it more difficult, the answer is at the end of this notebook

# %%
#Write your answer here
# investigating Pclass
print("pclass unique: ", df["pclass"].unique())
# Pclass is categorical and is the class the passengers where in 1 is first, 2 is 2nd and 3 is 3rd
# its oridinal so has ranking 1st -> 2nd -> 3rd

# invesigating  survived 
print("survived unique:", df["survived"].unique())
# Categorical nominal 0, is dead, 1 is alive

# investigating sibsp
print("sibsp unique:", df["sibsp"].unique())

#investigating parch
print("parch unique:", df["parch"].unique())

# investagting fare
print("fare unique:", df["fare"].unique())
# Out:
# pclass unique:  [1 2 3]
# survived unique: [1 0]
# sibsp unique: [0 1 2 3 4 5 8]
# parch unique: [0 2 1 4 3 5 6 9]
# fare unique: [211.3375 151.55    26.55    77.9583   0.      51.4792  49.5042 227.525
#   69.3     78.85    30.      25.925  247.5208  76.2917  75.2417  52.5542
#  221.7792  26.      91.0792 135.6333  35.5     31.     164.8667 262.375
#   55.      30.5     50.4958  39.6     27.7208 134.5     26.2875  27.4458
#  512.3292   5.      47.1    120.      61.175   53.1     86.5     29.7
#  136.7792  52.      25.5875  83.1583  25.7     71.      71.2833  57.
#   81.8583 106.425   56.9292  78.2667  31.6792  31.6833 110.8833  26.3875
#   27.75   263.     133.65    49.5     79.2     38.5    211.5     59.4
#   89.1042  34.6542  28.5    153.4625  63.3583  55.4417  76.7292  42.4
#   83.475   93.5     42.5     51.8625  50.      57.9792  90.      30.6958
#   80.      28.7125  25.9292  39.4     45.5    146.5208  82.1708  57.75
#  113.275   26.2833 108.9     25.7417  61.9792  66.6     40.125   55.9
#   60.      82.2667  32.3208  79.65    28.5375  33.5     34.0208  75.25
#   77.2875  61.3792  35.      24.      13.      11.5     10.5     12.525
#   39.      29.      21.      13.5     26.25    36.75    73.5     31.5
#   23.      32.5     13.8583  14.5     33.      65.      16.      12.275
#   27.      15.      13.7917  12.35    10.7083  41.5792  12.      12.875
#   15.0458  37.0042  15.5792  19.5     14.       9.6875  30.0708  13.8625
#   15.05    12.7375  15.0333  18.75    12.65    15.75     7.55    20.25
#    7.65     7.925    7.2292   7.25     8.05     9.475    9.35    18.7875
#    7.8875   7.05     8.3     22.525    7.8542  31.275    7.775    7.7958
#    7.8958  17.8     31.3875   7.225   14.4583  15.85    19.2583  14.4542
#    7.8792   4.0125  56.4958   7.75    15.2458  15.5     16.1      7.725
#    7.0458   7.2833   7.8208   6.75     8.6625   7.7333   7.4958   7.6292
#   15.9      8.1583  10.5167  10.1708   6.95    14.4     24.15    17.4
#    9.5     20.575   12.475   13.9      6.975   15.1     34.375    7.7417
#   20.525    7.85    46.9      8.3625   9.8458   8.85    19.9667  14.1083
#    6.8583   8.9625  12.2875   6.45     7.0542   8.1125   6.4958   8.6542
#   11.1333  23.45     9.825    7.125    8.4333   7.5208  13.4167   7.8292
#    7.7375  22.025   12.1833   9.5875   9.4833  25.4667   6.4375  15.55
#    7.5792   7.1417  23.25     7.7875   8.0292   8.4583  15.7417  11.2417
#    7.8      6.2375   9.225    3.1708   8.4042   7.3125   9.2167   8.6833
#   21.075   39.6875   8.7125  13.775    7.      22.3583   8.1375  29.125
#    7.7208  20.2125   7.7292   7.575   69.55     9.325   21.6792  16.7
#    7.7792  27.9         nan   9.8375  10.4625   8.5167   9.8417   9.
#   18.       7.875 ]

# %% [markdown]
# **T5) Get the shape of the dataframe**

# %%
#Write your answer here
df.shape
# Out:
# (1309, 11)

# %% [markdown]
# **T6) Get the name of the columns for the dataframe**

# %%
#Write your answer here

df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='str')

# %% [markdown]
# **T7) Do you think the columns (variables) need to be more readable? In particular, those that you might have found difficult to understand in T4**

# %%
#Write your answer here
df = df.rename({"sibsp": "siblings"}, axis=1)
df = df.rename({"parch" : "parents/childrens"}, axis=1)
df = df.rename({"pclass": "class"}, axis=1)
print(df.columns)
# Out:
# Index(['class', 'survived', 'name', 'sex', 'age', 'siblings',
#        'parents/childrens', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='str')

# %% [markdown]
# **T8) Are there any duplicated records?**

# %%
#Write your answer here
df[df.duplicated()]
# no there isnt
# Out:
# Empty DataFrame
# Columns: [class, survived, name, sex, age, siblings, parents/childrens, ticket, fare, cabin, embarked]
# Index: []

# %% [markdown]
# **T9) Copy the dataset so that you manipulate the copied dataset and leave the original unaffected**
#
# **Hint**: Check the pandas documentation for help on how to copy the dataframe

# %%
#Write your answer here
dfAltered = df.copy()

# %% [markdown]
# **T10) Create a new dataframe in which**
# * **a Missing variable (column) indicates the number of missing data for each variable in the titanic dataset**
# * **a Percentage variable indicates the percentage of the missing data over the size of the titanic dataset**
#
# **Print the records in this new dataframe sorted in descending order**

# %%
#Write your answer here
dfMissing = pd.DataFrame(columns=["Missing", "Percentage"])
missing = dfAltered.isna().sum()
missingpercetage = (dfAltered.isna().sum() / len(dfAltered)) * 100
dfMissing["Missing"] = missing
dfMissing["Percentage"] = missingpercetage 

dfMissing
# Out:
#                    Missing  Percentage
# class                    0    0.000000
# survived                 0    0.000000
# name                     0    0.000000
# sex                      0    0.000000
# age                    263   20.091673
# siblings                 0    0.000000
# parents/childrens        0    0.000000
# ticket                   0    0.000000
# fare                     1    0.076394
# cabin                 1014   77.463713
# embarked                 2    0.152788

# %% [markdown]
# **T11) What should we do with the variable with the highest number of missing data. Consider the amount of missing data compared to the total number of available data.**

# %%
#Write your answer here
# we should crop the columns becaue there is way too much missing data

dfAltered = dfAltered.drop(columns=["cabin"])

# %% [markdown]
# **T12) Impute the categorical variable(s) with the mode value**

# %%
#Write your answer here
dfAltered["embarked"] = dfAltered["embarked"].fillna(dfAltered["embarked"].mode()[0])
dfAltered.isna().sum()
# Out:
# class                  0
# survived               0
# name                   0
# sex                    0
# age                  263
# siblings               0
# parents/childrens      0
# ticket                 0
# fare                   1
# embarked               0
# dtype: int64

# %% [markdown]
# **T13i) Plot the histogram of the numeric variable with the largest number of missing data so as to determine the best value to fill in the missing data. Add suitable title and axis names.**
#
# **Note: You may want to use the native Pandas visualisation, matplotlib or seaborn**
#
# **Hint**: Check the relevant section from the Python Data Science Handbook (https://jakevdp.github.io/PythonDataScienceHandbook/04.05-histograms-and-binnings.html) or the Pandas documentation (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.hist.html)

# %%
#Write your answer here
import matplotlib.pyplot as plt

plt.hist(dfAltered["age"], bins=20)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Distribution of Age")
# Out:
# Text(0.5, 1.0, 'Distribution of Age')

# %% [markdown]
# **T13ii) Impute the numeric variable (just one) with an appropriate value**
#
# * State which value you use for imputation (e.g., mean or median), report the numerical value, and why this choice is appropriate for this variable.

# %%
#Write your answer here
# Going to use the median due to the skwewness of the data and the outliers around ages of 0, 5

dfAltered["age"] = dfAltered["age"].fillna(dfAltered.age.median())
dfAltered.isna().sum()
# Out:
# class                0
# survived             0
# name                 0
# sex                  0
# age                  0
# siblings             0
# parents/childrens    0
# ticket               0
# fare                 1
# embarked             0
# dtype: int64

# %% [markdown]
# **T13iii) Plot the histogram again for the variable from task T13 after imputation and observe how the distribution has changed.**

# %%
#Write your answer here
plt.hist(dfAltered["age"], bins=20)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Distribution of Age")
# Out:
# Text(0.5, 1.0, 'Distribution of Age')

# %% [markdown]
# **T14) Choose and apply an appropriate imputation method for the missing value. State the method used, the value applied, and justify your choice.**
#
# **Hint:** You may want to consider additional factors and use a more sophisticated imputation strategy

# %%
print(dfAltered.isna().sum())
# Out:
# class                0
# survived             0
# name                 0
# sex                  0
# age                  0
# siblings             0
# parents/childrens    0
# ticket               0
# fare                 0
# embarked             0
# dtype: int64

# %% [markdown]
# **T15i) Save the cleaned dataframe as a csv file with name "titanicClean.csv"**
#
# **Hint: Check the Pandas to_csv function**

# %%
#Write your answer here
dfAltered.to_csv("titanicClean.csv", index=False)

# %% [markdown]
# **T15ii) Load the cleaned dataset into a new dataframe**

# %%
#Write your answer here
df = pd.read_csv("titanicCLean.csv")

# %% [markdown]
# ***
#
# ### Part 3: Analysing the dataset

# %% [markdown]
# **T16) Get some descriptive statistics for the dataset selecting only the variables for which the descriptive statistics make sense**

# %%
#Write your answer here

print(df.columns)
print("Age standard deviation:", df.age.std())
print("Age mean:", df.age.mean())
print("Age Median:", df.age.median())
print("Age min:", df.age.min())
print("Age max:", df.age.max())

print("Siblings standard deviation:", df.siblings.std())
print("Siblings mean:", df.siblings.mean())
print("Siblings Median:", df.siblings.median())
print("Siblings min:", df.siblings.min())
print("Siblings max:", df.siblings.max())

print("Parents/Childrens standard deviation:", df["parents/childrens"].std())
print("Parents/Childrens mean:", df["parents/childrens"].mean())
print("Parents/Childrens Median:", df["parents/childrens"].median())
print("Parents/Childrens min:", df["parents/childrens"].min())
print("Parents/Childrens max:", df["parents/childrens"].max())

print("Fare standard deviation:", df.fare.std())
print("Fare mean:", df.fare.mean())
print("Fare Median:", df.fare.median())
print("Fare min:", df.fare.min())
print("Fare max:", df.fare.max())
# Out:
# Index(['class', 'survived', 'name', 'sex', 'age', 'siblings',
#        'parents/childrens', 'ticket', 'fare', 'embarked'],
#       dtype='str')
# Age standard deviation: 12.905240585464622
# Age mean: 29.50318563789152
# Age Median: 28.0
# Age min: 0.17
# Age max: 80.0
# Siblings standard deviation: 1.041658390596102
# Siblings mean: 0.4988540870893812
# Siblings Median: 0.0
# Siblings min: 0
# Siblings max: 8
# Parents/Childrens standard deviation: 0.8655602753495147
# Parents/Childrens mean: 0.3850267379679144
# Parents/Childrens Median: 0.0
# Parents/Childrens min: 0
# Parents/Childrens max: 9
# Fare standard deviation: 51.74364169511583
# Fare mean: 33.27607540106952
# Fare Median: 14.4542
# Fare min: 0.0
# Fare max: 512.3292

# %% [markdown]
# **T17i) For each passenger, find out how many family members she/he has in total and store this information as a new variable in the dataframe**

# %%
#Write your answer here
df["total_family"] = df["siblings"] + df["parents/childrens"]
    
df.head(5)
# Out:
#    class  survived                                             name     sex  \
# 0      1         1                    Allen, Miss. Elisabeth Walton  female
# 1      1         1                   Allison, Master. Hudson Trevor    male
# 2      1         0                     Allison, Miss. Helen Loraine  female
# 3      1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4      1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  siblings  parents/childrens  ticket      fare embarked  total_family
# 0  29.00         0                  0   24160  211.3375        S             0
# 1   0.92         1                  2  113781  151.5500        S             3
# 2   2.00         1                  2  113781  151.5500        S             3
# 3  30.00         1                  2  113781  151.5500        S             3
# 4  25.00         1                  2  113781  151.5500        S             3

# %% [markdown]
# **T17ii) Print the records for the family with surname "Palsson" and confirm that the result from task T17i is correct**

# %%
#Write your answer here
print(df[df.name.str.contains("Palsson")])
# Out:
#       class  survived                                         name     sex  \
# 1096      3         0               Palsson, Master. Gosta Leonard    male
# 1097      3         0                  Palsson, Master. Paul Folke    male
# 1098      3         0                   Palsson, Miss. Stina Viola  female
# 1099      3         0                Palsson, Miss. Torborg Danira  female
# 1100      3         0  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female
#
#        age  siblings  parents/childrens  ticket    fare embarked  total_family
# 1096   2.0         3                  1  349909  21.075        S             4
# 1097   6.0         3                  1  349909  21.075        S             4
# 1098   3.0         3                  1  349909  21.075        S             4
# 1099   8.0         3                  1  349909  21.075        S             4
# 1100  29.0         0                  4  349909  21.075        S             4

# %% [markdown]
# **T18): Find out and print the details of the biggest family on board**
#
# **Hint: You may want to check https://en.wikipedia.org/wiki/Passengers_of_the_Titanic or https://titanicfacts.net/titanic-passenger-list**
#
# Also read: https://en.wikipedia.org/wiki/Passengers_of_the_Titanic#Third_class

# %%
#Write your answer here
print(df[df["total_family"] == df["total_family"].max()])
# Out:
#       class  survived                               name     sex   age  \
# 1170      3         0         Sage, Master. Thomas Henry    male  28.0
# 1171      3         0        Sage, Master. William Henry    male  14.5
# 1172      3         0                    Sage, Miss. Ada  female  28.0
# 1173      3         0       Sage, Miss. Constance Gladys  female  28.0
# 1174      3         0  Sage, Miss. Dorothy Edith "Dolly"  female  28.0
# 1175      3         0            Sage, Miss. Stella Anna  female  28.0
# 1176      3         0           Sage, Mr. Douglas Bullen    male  28.0
# 1177      3         0                Sage, Mr. Frederick    male  28.0
# 1178      3         0           Sage, Mr. George John Jr    male  28.0
# 1179      3         0              Sage, Mr. John George    male  28.0
# 1180      3         0     Sage, Mrs. John (Annie Bullen)  female  28.0
#
#       siblings  parents/childrens    ticket   fare embarked  total_family
# 1170         8                  2  CA. 2343  69.55        S            10
# 1171         8                  2  CA. 2343  69.55        S            10
# 1172         8                  2  CA. 2343  69.55        S            10
# 1173         8                  2  CA. 2343  69.55        S            10
# 1174         8                  2  CA. 2343  69.55        S            10
# 1175         8                  2  CA. 2343  69.55        S            10
# 1176         8                  2  CA. 2343  69.55        S            10
# 1177         8                  2  CA. 2343  69.55        S            10
# 1178         8                  2  CA. 2343  69.55        S            10
# 1179         1                  9  CA. 2343  69.55        S            10
# 1180         1                  9  CA. 2343  69.55        S            10

# %% [markdown]
# **T19i) How was the ticket fare for class 1 distributed? Generate a boxplot and investigate whether there are any interesting insights**
#
# **Hint**: You may want to check: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html

# %%
#Write your answer here
dfFirstClass = df[df["class"] == 1]
dfFirstClass.boxplot(column=["fare"])

# couple outliers up to around 500
# Out:
# <Axes: >

# %% [markdown]
# **T19ii) Do you see any weird fare values? Check if there are any outliers for the ticket fares of class 1 using the standard deviation method.**

# %%
#Write your answer here

stdFare = dfFirstClass.fare.std()
print("Standard Deviation of Fare for First Class Passengers:", stdFare)

#there are about 4 outliers
# Out:
# Standard Deviation of Fare for First Class Passengers: 80.44717824890336

# %% [markdown]
# **T19iii) Print the information for those passengers**
#
# You can read the interesting story of the passengers and their families at:
# - https://www.encyclopedia-titanica.org/titanic-survivor/charlotte-cardeza.html
# - https://www.encyclopedia-titanica.org/titanic-survivor/annie-moore-ward.html

# %%
#Write your answer here
print(dfFirstClass[dfFirstClass["fare"] > stdFare * 3])
# Out:
#      class  survived                                               name  \
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 35       1         1                           Bowen, Miss. Grace Scott
# 49       1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50       1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 66       1         1                        Chaudanson, Miss. Victorine
# 97       1         1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 111      1         1                     Fortune, Miss. Alice Elizabeth
# 112      1         1                         Fortune, Miss. Ethel Flora
# 113      1         1                         Fortune, Miss. Mabel Helen
# 114      1         0                     Fortune, Mr. Charles Alexander
# 115      1         0                                  Fortune, Mr. Mark
# 116      1         1                Fortune, Mrs. Mark (Mary McDougald)
# 183      1         1                             Lesurer, Mr. Gustave J
# 249      1         1                        Ryerson, Master. John Borie
# 250      1         1                         Ryerson, Miss. Emily Borie
# 251      1         1              Ryerson, Miss. Susan Parker "Suzette"
# 252      1         0                         Ryerson, Mr. Arthur Larned
# 253      1         1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 302      1         1                                   Ward, Miss. Anna
#
#         sex   age  siblings  parents/childrens    ticket      fare embarked  \
# 16     male  24.0         0                  1  PC 17558  247.5208        C
# 17   female  50.0         0                  1  PC 17558  247.5208        C
# 35   female  45.0         0                  0  PC 17608  262.3750        C
# 49     male  36.0         0                  1  PC 17755  512.3292        C
# 50   female  58.0         0                  1  PC 17755  512.3292        C
# 66   female  36.0         0                  0  PC 17608  262.3750        C
# 97   female  27.0         1                  1  PC 17558  247.5208        C
# 111  female  24.0         3                  2     19950  263.0000        S
# 112  female  28.0         3                  2     19950  263.0000        S
# 113  female  23.0         3                  2     19950  263.0000        S
# 114    male  19.0         3                  2     19950  263.0000        S
# 115    male  64.0         1                  4     19950  263.0000        S
# 116  female  60.0         1                  4     19950  263.0000        S
# 183    male  35.0         0                  0  PC 17755  512.3292        C
# 249    male  13.0         2                  2  PC 17608  262.3750        C
# 250  female  18.0         2                  2  PC 17608  262.3750        C
# 251  female  21.0         2                  2  PC 17608  262.3750        C
# 252    male  61.0         1                  3  PC 17608  262.3750        C
# 253  female  48.0         1                  3  PC 17608  262.3750        C
# 302  female  35.0         0                  0  PC 17755  512.3292        C
#
#      total_family
# 16              1
# 17              1
# 35              0
# 49              1
# 50              1
# 66              0
# 97              2
# 111             5
# 112             5
# 113             5
# 114             5
# 115             5
# 116             5
# 183             0
# 249             4
# 250             4
# 251             4
# 252             4
# 253             4
# 302             0

# %% [markdown]
# **T20) Given that Titanic stopped in three ports (C = Cherbourg, Q = Queenstown, S = Southampton) before departing from the UK, can we identify any patterns regarding the ports at which passengers embarked on the Titanic? Produce a bar plot to illustrate this**
#
# **Hint:** You may want to check: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html

# %%
#Write your answer here
df.plot.bar(x="embarked", y="class")
# Out:
# <Axes: xlabel='embarked'>

# %% [markdown]
# **T21) Was there any bias in those survived based on their ticket class? Produce a grouped barplot to demonstrate the difference between those who survived and those who did not based on ticket class. What do you observe?**

# %%
#Write your answer here
df.plot.bar.

# %% [markdown]
# ## Brain Teaser

# %% [markdown]
# **BT1) Generate a new column 'Title' that includes the title of each passenger and has only the following entries:**
# * Master, Miss, Mr, Mss
#
# where
# * Miss includes also Mlle and Ms
# * Mme includes also Mrs
# * all the remaining titles become Rare
#
# **Append the column before the name**

# %%
#Write your answer here

# %% [markdown]
# **BT2) Using the outcome of BT1, print the percentage of survived passengers based on their title**

# %%
#Write your answer here

# %%
# Answers to T4
# - Pclass     Ticket class	     
# - SibSp      # of siblings/spouses aboard the Titanic
# - Parch      # of parents / children aboard the Titanic
